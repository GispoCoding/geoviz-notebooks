# %% [markdown]
# 0) Imports and database config

# %%
# %config Completer.use_jedi = False  # why on earth is this not default

import sys
from h3 import geo_to_h3, h3_to_geo
from ipygis import get_connection_url, to_gdf, get_map, get_h3_map
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely import wkb
from shapely.geometry import Point
from sqlalchemy import create_engine, func, Column, Integer, Float
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.dialects.postgresql import JSONB
from geoalchemy2 import Geometry
from geoalchemy2.shape import to_shape

# %%
sql_url = get_connection_url(dbname='geoviz')
engine = create_engine(sql_url)
session = sessionmaker(bind=engine)()

# %%
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/geoviz)

# %% [markdown]
# 1) Define the desired tables as below, or use sqlalchemy autofind to automatically define the classes based on the imported OSM tables?
#
# The OSM import contains tables `osmpoints`, `osmboundaries`, `osmlines`, `osmpolygons`, `osmroutes`
# The Flickr import contains `flickrpoints`

# %%
sys.path.insert(0, '..')
from models import OSMPoint, OSMPolygon, FlickrPoint

# %%
OSMPoint.__table__
# Out:
# Table('osmpoints', MetaData(), Column('node_id', BigInteger(), table=<osmpoints>, primary_key=True, nullable=False), Column('tags', JSONB(astext_type=Text()), table=<osmpoints>), Column('geom', Geometry(from_text='ST_GeomFromEWKT', name='geometry'), table=<osmpoints>), schema=None)

# %%
OSMPolygon.__table__
# Out:
# Table('osmpolygons', MetaData(), Column('area_id', BigInteger(), table=<osmpolygons>, primary_key=True, nullable=False), Column('tags', JSONB(astext_type=Text()), table=<osmpolygons>), Column('geom', Geometry(from_text='ST_GeomFromEWKT', name='geometry'), table=<osmpolygons>), schema=None)

# %%
FlickrPoint.__table__
# Out:
# Table('flickrpoints', MetaData(), Column('point_id', BigInteger(), table=<flickrpoints>, primary_key=True, nullable=False), Column('properties', JSONB(astext_type=Text()), table=<flickrpoints>), Column('geom', Geometry(from_text='ST_GeomFromEWKT', name='geometry'), table=<flickrpoints>), schema=None)

# %% [markdown]
# 2) How to query PostGIS

# %%
session.query(OSMPoint).count()
# Out:
# 984889

# %%
session.query(OSMPolygon).count()
# Out:
# 3389830

# %%
session.query(FlickrPoint).count()
# Out:
# 73083

# %%
first_point=session.query(OSMPoint).first()
first_point.geom
# Out:
# <WKBElement at 0x1373a7a30; 0101000020110f00005d22d818a574464191253da77bfd5f41>

# %%
first_point.tags
# Out:
# {'ref': '38', 'description': 'Eesti Vabariigi territoriaalmere piir'}

# %%
first_polygon=session.query(OSMPolygon).first()
first_polygon.geom
# Out:
# <WKBElement at 0x1374351f0; >

# %%
first_polygon.tags
# Out:
# {'natural': 'coastline'}

# %% [markdown]
# 3) OSM data is contained in the tags JSON field. Make PostGIS queries to JSON fields as below.

# %%
session.query(OSMPolygon).filter(OSMPolygon.tags['place'].astext=='islet').count()
# Out:
# 47847

# %%
restaurants = session.query(OSMPoint).filter(OSMPoint.tags['amenity'].astext=='restaurant')
restaurants.count()
# Out:
# 4210

# %%
bars = session.query(OSMPoint).filter(OSMPoint.tags['amenity'].astext=='bar')
bars.count()
# Out:
# 444

# %%
pubs = session.query(OSMPoint).filter(OSMPoint.tags['amenity'].astext=='pub')
pubs.count()
# Out:
# 1117

# %% [markdown]
# There are also some polygons with amenities, so you may take them into account separately if you need them

# %%
session.query(OSMPolygon).filter(OSMPolygon.tags['amenity'].astext=='restaurant').count()
# Out:
# 429

# %%
for restaurant in restaurants:
    print(restaurant.tags)
# Out:
# {'amenity': 'restaurant'}
# {'name': 'Ravintola HSF', 'amenity': 'restaurant', 'name:fi': 'Ravintola HSF', 'name:sv': 'Restaurant HSF'}
# {'name': 'SEO-restaurang', 'amenity': 'restaurant', 'addr:city': 'Raseborg', 'addr:street': 'Järnösundsvägen', 'addr:housename': 'Predium hamn', 'addr:housenumber': '136'}
# {'name': 'Neljän tuulen tupa', 'amenity': 'restaurant', 'name:fi': 'Neljän tuulen tupa', 'name:sv': 'De fyra vindarnas hus'}
# {'name': 'Hangon Casino', 'amenity': 'restaurant', 'addr:street': 'Appelgrenintie', 'addr:housenumber': '10'}
# {'name': 'HanDeli', 'amenity': 'restaurant'}
# {'name': 'Makaronitehdas', 'email': 'hanko@hangonmakaronitehdas.fi', 'phone': '+358445234522', 'amenity': 'restaurant', 'cuisine': 'pasta', 'website': 'http://www.hangonmakaronitehdas.fi', 'addr:street': 'Satamakatu', 'addr:postcode': '10900', 'addr:housenumber': '15'}
# {'name': 'Classic Pizza Hanko', 'amenity': 'restaurant', 'cuisine': 'pizza'}
# {'name': 'Ravintola Makasiini', 'phone': '044-5234522', 'amenity': 'restaurant', 'name:fi': 'Ravintola Makasiini', 'name:sv': 'Restaurant Makasiini', 'website': 'http://www.hangonmakaronitehdas.fi', 'addr:street': 'Satamakatu', 'addr:housenumber': '15'}
# {'name': 'Ravintola Pirate', 'amenity': 'restaurant', 'name:fi': 'Ravintola Pirate', 'name:sv': 'Restaurant Pirate', 'website': 'http://www.pirate.fi/?pinc=1&lng=hanko'}
# {'name': 'Origi', 'amenity': 'restaurant', 'name:en': 'Origo', 'name:fi': 'Origo', 'name:sv': 'Origo', 'addr:street': 'Satamakatu'}
# {'name': 'Ravintola Origo', 'amenity': 'restaurant', 'name:fi': 'Ravintola Origo', 'name:sv': 'Restaurant Origo'}
# {'name': 'Makana Asian cuisine', 'amenity': 'restaurant'}
# {'name': 'På Kroken', 'amenity': 'restaurant'}
# {'amenity': 'restaurant'}
# {'name': 'Brudhäll', 'amenity': 'restaurant'}
# {'name': 'Adlon Pizzeria & Sportsbar', 'amenity': 'restaurant', 'cuisine': 'pizza', 'addr:city': 'Mariehamn', 'addr:street': 'Hamngatan', 'addr:country': 'AX', 'addr:postcode': '22100', 'contact:phone': '+358 18 12345', 'opening_hours': 'Mo-Su 13:00-24:00', 'contact:website': 'http://www.pizza.ax', 'addr:housenumber': '7'}
# {'name': 'Västernäs Pizza & Asian', 'phone': '+358 18 17555', 'amenity': 'restaurant', 'cuisine': 'pizza;asian', 'takeaway': 'yes', 'addr:street': 'Doppingvägen', 'opening_hours': 'Mo-Th 11:00-20:00; Fr 11:00-21:00; Sa-Su 14:00-21:00'}
# {'name': 'Bistro Koppargrytan', 'email': 'koppar-grytan@hotmail.se', 'phone': '+358 18 31446', 'amenity': 'restaurant', 'wheelchair': 'yes', 'description': 'Bra mat till bra pris - det är vårt motto på Bistro Koppargrytan! Den familjära atmosfären bjuder in såväl barn som äldre, business som grovjobbare. Lunch, middag, pizza och hamburgare är vad vi erbjuder till den hungriga.', 'kitchen_hours': 'Mo-Fr 09:30-19:00; Sa 10:00-17:00; Su 12:00-17:00', 'opening_hours': 'Mo-Fr 10:00-18:00; Sa 10:00-16:00; Su 11:00-16:00', 'kitchen_hours:pizza': 'Mo-Fr 10:30-19:30; Sa 11:00-17:30; Su 12:00-17:30'}
# {'name': 'Venezia', 'amenity': 'restaurant', 'cuisine': 'pizza'}
# {'name': 'Övningsrestaurang hjorten', 'email': 'jan-erik.sundstrom@gymnasium.ax', 'phone': '+358 (0)18 26044', 'amenity': 'restaurant', 'website': 'http://hjorten.gymnasium.ax', 'opening_hours': 'Sa,Su 10:00-14:00'}
# {'name': 'Time Out', 'phone': '+3581812006', 'amenity': 'restaurant', 'takeaway': 'yes', 'addr:city': 'Mariehamn', 'wheelchair': 'yes', 'addr:street': 'Elverksgatan', 'description': 'Open Monday to Friday 08:00-15:00, lunch served 10:30-13:30.', 'addr:postcode': '22100', 'opening_hours': 'Mo-Fr 08:00-15:00', 'internet_access': 'wlan', 'addr:housenumber': '10'}
# {'name': 'Åss Paviljongen', 'amenity': 'restaurant', 'cuisine': 'regional', 'smoking': 'no', 'website': 'https://www.paviljongen.ax/', 'addr:city': 'Mariehamn', 'wheelchair': 'no', 'addr:street': 'Sjöpromenaden', 'addr:postcode': '22100', 'opening_hours': 'Mo-Fr 11:00-22:00, Sa-Su 12:00-22:00'}
# {'name': 'Nautical', 'email': 'info@nautical.ax', 'phone': '+358 (0)18 19 931', 'amenity': 'restaurant', 'website': 'http://www.nautical.ax', 'addr:city': 'Mariehamn', 'addr:street': 'Hamngatan', 'survey:date': '2014-01-18', 'kitchen_hours': 'Mo,Tu 11:00-14:00; We-Fr 11:00-21:00; Sa 17:00-21:00', 'opening_hours': 'Mo,Tu 11:00-14:00; We,Th 11:00-23:00; Fr 11:00-24:00; Sa 17:00-24:00', 'addr:housenumber': '2'}
# {'name': 'Björntjänster', 'amenity': 'restaurant', 'opening_hours': 'Mo-Fr 11:00-14:00'}
# {'name': 'Nordic Sushi', 'amenity': 'restaurant', 'cuisine': 'sushi', 'takeaway': 'yes', 'addr:city': 'Mariehamn', 'wheelchair': 'no', 'addr:street': 'Styrmansgatan', 'opening_hours': 'Tu-Fr 11:00-18:00; Sa-Su 13:00-18:00', 'addr:housenumber': '4'}
# {'name': 'Khun Mom', 'amenity': 'restaurant', 'cuisine': 'thai', 'takeaway': 'yes', 'addr:street': 'Köpmansgatan', 'addr:housenumber': '1', 'contact:facebook': 'https://www.facebook.com/Khun-Mom-108059323985634'}
# {'name': 'Royal Pizza & Grill', 'amenity': 'restaurant', 'cuisine': 'pizza;burger;kebab', 'website': 'https://www.royal.ax/', 'delivery': 'yes', 'takeaway': 'yes', 'wheelchair': 'no', 'addr:street': 'Torggatan', 'opening_hours': 'Mo-Fr 10:30-22:00; Sa-Su 12:00-22:00', 'addr:housenumber': '1'}
# {'name': 'Pizza Diablo', 'email': 'info@diablo.ax', 'phone': '+3581817100', 'amenity': 'restaurant', 'cuisine': 'pizza', 'website': 'https://diablo.ax/', 'delivery': 'no', 'takeaway': 'yes', 'addr:city': 'Mariehamn', 'addr:street': 'Nygatan', 'description': 'Outdoor seating in the summer.', 'survey:date': '2014-09-02', 'addr:postcode': '22100', 'opening_hours': 'Mo-Th 16:00-21:00; Fr 11:00-24:00; Sa 12:00-24:00; Su 12:00-21:00', 'outdoor_seating': 'yes', 'addr:housenumber': '3'}
# {'name': 'Eden Rock', 'amenity': 'restaurant', 'addr:city': 'Mariehamn', 'addr:street': 'Ålandsvägen', 'addr:country': 'AX', 'opening_hours': 'Mo-Th 11:00-22:00; Fr 11:00-02:00; Sa 15:00-02:00; Su 15:00-22:00', 'addr:housenumber': '40'}
# {'bar': 'yes', 'name': 'Kvarter5', 'email': 'info@kvarter5.ax', 'phone': '+358 18 15 555', 'amenity': 'restaurant', 'website': 'http://www.kvarter5.ax/', 'addr:city': 'Mariehamn', 'addr:street': 'Norragatan', 'addr:postcode': '22100', 'opening_hours': 'Mo-Th 11:00-14:00,17:00-22:00; Fr 11:00-14:00,17:00-24:00; Sa 17:00-24:00', 'outdoor_seating': 'yes', 'addr:housenumber': '10', 'opening_hours:covid19': 'off'}
# {'name': 'Sagulthai', 'amenity': 'restaurant', 'cuisine': 'thai', 'wheelchair': 'yes'}
# {'name': 'Nonna Rina', 'amenity': 'restaurant', 'cuisine': 'italian'}
# {'name': 'Bistro Avenue', 'phone': '+358 18 14900', 'amenity': 'restaurant', 'wheelchair': 'no', 'addr:housenumber': '2'}
# {'name': 'Ångbåtsbryggan Äventyrsgolf', 'amenity': 'restaurant', 'cuisine': 'ice_cream', 'wheelchair': 'no'}
# {'name': 'Brasserie Ångbåtsbryggan', 'amenity': 'restaurant', 'website': 'https://www.brasserie.ax/', 'wheelchair': 'yes'}
# {'name': 'Boquerian', 'level': '0', 'phone': '+358 (0)18 17 660', 'amenity': 'restaurant', 'cuisine': 'tapas', 'start_date': '2019-07-20', 'wheelchair': 'yes', 'opening_hours': 'Mo-Th 11:00-22:00; Fr 11:00-23:00; Sa 12:00-23:00', 'opening_hours:kitchen': 'Mo-Th 11:00-21:00; Fr 11:00-22:00; Sa 12:00-22:00; Su 11:00-15:00'}
# {'bar': 'yes', 'name': 'Compagniet', 'amenity': 'restaurant'}
# {'bar': 'yes', 'fax': '+358 18 12467', 'name': 'Dinos Bar & Grill', 'email': 'info@dinosbar.com', 'phone': '+358 18 13939', 'amenity': 'restaurant', 'website': 'http://www.dinosbar.com', 'delivery': 'no', 'addr:city': 'Mariehamn', 'addr:street': 'Strandgatan', 'description': 'Outdoor seating in the summer.', 'addr:postcode': '22100', 'opening_hours': 'Mo-Th 15:00-21:00; Fr 15:00-22:00; Sa 15:00-22:00; Su 15:00-21:00', 'outdoor_seating': 'yes', 'addr:housenumber': '12'}
# {'name': 'Indigo', 'phone': '+3581816550', 'amenity': 'restaurant', 'cuisine': 'international', 'website': 'http://www.indigo.ax/', 'addr:city': 'Mariehamn', 'wheelchair': 'limited', 'addr:street': 'Nygatan', 'addr:country': 'AX', 'opening_hours': 'Mo-Th 11:00-24:00; Fr 11:00-03:00; Sa 12:00-03:00; Su 14:00-24:00', 'addr:housenumber': '1'}
# {'name': 'Kotipizza', 'brand': 'Kotipizza', 'phone': '+358 18 12110', 'amenity': 'restaurant', 'cuisine': 'pizza', 'website': 'https://www.kotipizza.fi/', 'takeaway': 'yes', 'addr:city': 'Mariehamn', 'addr:street': 'Nygatan', 'addr:postcode': '22100', 'outdoor_seating': 'no', 'addr:housenumber': '1'}
# {'name': 'Club Marin', 'amenity': 'restaurant'}
# {'name': 'Pub Niska', 'amenity': 'restaurant', 'cuisine': 'pizza', 'addr:city': 'Mariehamn', 'addr:country': 'AX', 'addr:postcode': '22100', 'opening_hours': 'Mo-Sa 11:00-19:00;Su 14:00-20:00', 'outdoor_seating': 'yes'}
# {'name': 'Fananamma', 'email': 'info@fananamma.com', 'amenity': 'restaurant', 'website': 'https://fananamma.com', 'takeaway': 'yes', 'addr:city': 'Jomala', 'addr:street': 'Jomalagårdsväg', 'addr:postcode': '22150', 'opening_hours': 'Mo-Fr 11:15 - 14:00', 'diet:sugar_free': 'yes', 'addr:housenumber': '16'}
# {'name': 'Maneechay Thai Restaurant', 'amenity': 'restaurant', 'cuisine': 'thai', 'contact:facebook': 'https://www.facebook.com/Restaurant.Maneechay/'}
# {'name': 'Stallhagen', 'amenity': 'restaurant', 'website': 'http://www.stallhagen.com/', 'opening_hours': 'Mo-Su 11:00-22:00'}
# {'name': 'Restaurang Q', 'amenity': 'restaurant', 'cuisine': 'regional'}
# {'name': 'Centrumbaren', 'amenity': 'restaurant'}
# {'name': 'Bettys', 'email': 'info@bettys.ax', 'phone': '+3581838058', 'amenity': 'restaurant', 'website': 'https://www.bettys.ax/', 'wheelchair': 'limited', 'addr:street': 'Bagargatan', 'outdoor_seating': 'no', 'addr:housenumber': '3'}
# {'name': 'bodegan', 'amenity': 'restaurant', 'cuisine': 'coffee_shop;pizza;international;ice_cream;burger'}
# {'name': 'Käringsund', 'amenity': 'restaurant'}
# {'name': 'Soltuna Restaurang & Café', 'email': 'info@soltuna.ax', 'phone': '+358 18 49530', 'amenity': 'restaurant', 'website': 'https://soltuna.ax/', 'addr:city': 'Geta', 'addr:street': 'Getabergsvägen', 'addr:postcode': '22340', 'outdoor_seating': 'yes'}
# {'amenity': 'restaurant'}
# {'name': 'Trixies', 'amenity': 'restaurant', 'addr:city': 'Brändö', 'addr:postcode': '22920'}
# {'name': 'Galeasen', 'amenity': 'restaurant', 'opening_hours': 'Jun 23-Aug 05 12:00-22:30; Aug 06-25 18:00-22:00'}
# {'name': 'Kastören', 'amenity': 'restaurant'}
# {'name': 'Jan Karlsgårdens wärdshus', 'amenity': 'restaurant', 'opening_hours': 'Mo-Su,PH 10:00-17:00', 'outdoor_seating': 'yes'}
# {'name': 'Smakbyn', 'email': 'info@smakbyn.ax', 'phone': '+358 18 43666', 'amenity': 'restaurant', 'website': 'https://www.smakbyn.ax/', 'wheelchair': 'yes', 'kitchen_hours': 'Mo-Fr 11:00-20:00; Sa,Su 12:00-21:00', 'toilets:wheelchair': 'yes'}
# {'name': 'Mormorsgrönahus', 'email': 'boka@mormors.ax', 'phone': '+358 457 345 0323', 'amenity': 'restaurant', 'website': 'http://www.mormors.ax'}
# {'name': 'Lilla Bangkok', 'phone': '+358 40 879 5271', 'amenity': 'restaurant', 'website': 'https://www.facebook.com/sumaleegr', 'takeaway': 'yes'}
# {'name': 'Degerby Mat och Café', 'amenity': 'restaurant'}
# {'name': 'Restaurant Seagram', 'amenity': 'restaurant'}
# {'amenity': 'restaurant'}
# {'name': 'Havspaviljongen', 'amenity': 'restaurant', 'website': 'http://www.havspaviljongen.com/'}
# {'amenity': 'restaurant'}
# {'name': 'Buffalo', 'amenity': 'restaurant'}
# {'phone': '+35824633407', 'amenity': 'restaurant', 'name:en': 'Grill Café Skagen', 'website': 'https://skagen.fi/', 'addr:street': 'Näsbyvägen', 'addr:postcode': '21760', 'opening_hours': 'Mo-Su 11:00-22:00', 'addr:housenumber': '190'}
# {'amenity': 'restaurant'}
# {'name': 'Vuosnaisten meriasema', 'email': 'meriasema@kustavi.net', 'phone': '+3582877512', 'amenity': 'restaurant', 'cuisine': 'regional;burger;seafood', 'smoking': 'outside', 'website': 'https://www.vuosnaistenmeriasema.com/ravintolapalvelut', 'addr:city': 'Kustavi', 'addr:street': 'Vuosnaistentie', 'addr:postcode': '23360', 'opening_hours': 'Mo-Su 09:00-21:00', 'outdoor_seating': 'yes', 'addr:housenumber': '616'}
# {'name': 'Vartsalan Vanha Koulu', 'email': 'info@vartsalanvanhakoulu.fi', 'phone': '+358 400 199 757', 'amenity': 'restaurant', 'cuisine': 'pizza;regional', 'smoking': 'outside', 'website': 'https://www.vartsalanvanhakoulu.fi/', 'addr:city': 'Kustavi', 'addr:unit': 'B', 'addr:street': 'Vartsalantie', 'addr:postcode': '23360', 'opening_hours': 'Mo-Su 10:00-20:00', 'outdoor_seating': 'yes', 'addr:housenumber': '118'}
# {'name': "Laura Peterzen's", 'amenity': 'restaurant'}
# {'name': 'Merideli Leonella', 'phone': '+358405905794', 'amenity': 'restaurant', 'cuisine': 'coffee_shop;pizza', 'name:en': 'Leonella', 'website': 'https://fb.me/leonellainio', 'addr:postcode': '23390', 'opening_hours': 'Mo-Su 10:00-22:00'}
# {'name': 'Rantaklubi', 'amenity': 'restaurant'}
# {'name': 'Vaihela', 'amenity': 'restaurant', 'cuisine': 'fish', 'website': 'http://www.vaihela.fi', 'addr:housename': 'Vaihela'}
# {'name': 'Ravintola Röölänranta', 'amenity': 'restaurant', 'contact:website': 'http://roola.fi/'}
# {'email': 'info@taattistentila.fi', 'amenity': 'restaurant', 'smoking': 'outside', 'description': 'Kahvila-ravintola ja toimisto. Ravintola, Juhlatila, A-oikeudet', 'outdoor_seating': 'yes'}
# {'name': 'Naapuri', 'amenity': 'restaurant'}
# {'name': 'Merimaskun Rantamakasiini', 'amenity': 'restaurant'}
# {'name': 'Naantalin metsätähti', 'email': 'susanna@naantalinmetsatahti.fi', 'phone': '+358 44 583 9789', 'amenity': 'restaurant', 'smoking': 'outside', 'addr:city': 'Naantali', 'addr:street': 'Immastentie', 'description': 'Metsätähti on lähiruokaa ja laadukkaita tilauspalveluita tarjoava ravintola Naantalin Soinisissa.', 'addr:postcode': '21110', 'opening_hours': 'Mo-Fr 09:00-16:30', 'addr:housenumber': '1', 'air_conditioning': 'yes'}
# {'name': 'Le Soleil', 'phone': '+358 2 44 550', 'amenity': 'restaurant', 'website': 'https://www.naantalispa.fi/', 'addr:city': 'Naantali', 'addr:street': 'Matkailijantie', 'addr:country': 'FI', 'addr:postcode': '21100', 'addr:housenumber': '2'}
# {'name': 'Mamman keittiö', 'is_in': 'Muumimaailma, Naantali, Finland', 'amenity': 'restaurant', 'addr:city': 'Naantali', 'addr:country': 'FI'}
# {'name': 'Hastalapasta', 'amenity': 'restaurant', 'website': 'http://hastalapasta.fi/'}
# {'name': 'Uusi Kilta', 'amenity': 'restaurant', 'website': 'https://www.uusikilta.fi/'}
# {'name': 'Snickari', 'phone': '+358 2 445 599', 'amenity': 'restaurant', 'website': 'https://www.snickari.fi/', 'addr:city': 'Naantali', 'addr:street': 'Mannerheiminkatu', 'addr:country': 'FI', 'addr:postcode': '21100', 'outdoor_seating': 'yes', 'addr:housenumber': '2', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Kaivohuone', 'amenity': 'restaurant', 'addr:city': 'Naantali', 'addr:country': 'FI'}
# {'name': 'Ravintola Trappi', 'amenity': 'restaurant', 'website': 'http://www.ravintolatrappi.fi', 'old_name': 'Kala-Trappi', 'addr:city': 'Naantali', 'addr:country': 'FI'}
# {'name': 'Trapinpiha', 'amenity': 'restaurant', 'addr:city': 'Naantali', 'addr:country': 'FI'}
# {'url': 'http://www.merisali.fi', 'name': 'Kahvila-Ravintola Merisali', 'amenity': 'restaurant', 'cuisine': 'regional', 'addr:city': 'Naantali', 'addr:country': 'FI'}
# {'name': 'Martelino', 'amenity': 'restaurant', 'website': 'http://martelino.fi/', 'addr:city': 'Naantali', 'addr:street': 'Tullikatu', 'addr:postcode': '21100', 'addr:housenumber': '11'}
# {'name': 'Kultaranta Heineken House', 'phone': '+35875326 6000', 'amenity': 'restaurant', 'website': 'https://kultarantaresort.fi/heineken-house/', 'addr:city': 'Naantali', 'addr:street': 'Särkänsalmentie', 'addr:postcode': '21100', 'addr:housenumber': '178', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Kultaranta Resort', 'amenity': 'restaurant', 'tourism': 'hotel'}
# {'name': 'Arvin pito ja lounas', 'phone': '+358407016626', 'amenity': 'restaurant', 'website': 'https://www.arvinpitojalounas.fi', 'addr:city': 'Turku', 'addr:street': 'Suvilinnantie', 'addr:postcode': '20900', 'addr:housenumber': '2', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Kebab pizzeria quattro', 'phone': '+358 44 9895111', 'amenity': 'restaurant', 'opening_hours': 'Mo-Su,PH 10:30-21:00', 'opening_hours:covid19': 'Mo-Su 10:30-21:00'}
# {'bar': 'yes', 'name': 'Terrassen', 'amenity': 'restaurant', 'website': 'https://www.barterrassen.com', 'addr:city': 'Turku', 'addr:street': 'Valaanpyytäjänkatu', 'opening_hours': 'We-Th 15:30-21:00; Fr 15:30-22:00; Sa 14:00-22:00; Su-Tu closed', 'addr:housenumber': '10'}
# {'name': 'Ruissalon Maininki', 'is_in': 'Turku, Finland', 'amenity': 'restaurant', 'operator': 'Turun Pursiseura ry'}
# {'name': 'Ravintola 3. linja', 'email': 'ravintola@kolmaslinja.fi', 'phone': '+358 50 462 1727', 'amenity': 'restaurant', 'website': 'https://kolmaslinja.fi/', 'alt_name': 'Kolmas linja'}
# {'name': 'Teboil Herkku', 'amenity': 'restaurant', 'website': 'https://www.tbherkku.fi/ravintola/', 'addr:city': 'Turku', 'addr:street': 'Rautatehtaankatu', 'addr:postcode': '20200', 'addr:housenumber': '1', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'ABC Raisio', 'amenity': 'restaurant', 'addr:city': 'Raisio', 'addr:street': 'Piilipuunkatu', 'addr:postcode': '21200', 'opening_hours': 'Mo-Su 06:00-24:00', 'addr:housenumber': '2', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Pho Ngon', 'phone': '0442588811', 'amenity': 'restaurant', 'cuisine': 'vietnamese', 'name:en': 'Pho Ngon', 'name:fi': 'Pho Ngon', 'name:sv': 'Pho Ngon', 'website': 'https://m.facebook.com/phongonvietnamesecuisine/?locale2=fi_FI', 'addr:street': 'Tuotekatu 7', 'addr:postcode': '21200', 'opening_hours': 'Mo-Fr 10:30-15:00'}
# {'name': 'Classic Pizza Restaurant', 'level': '1', 'amenity': 'restaurant', 'cuisine': 'pizza', 'addr:city': 'Raisio', 'addr:street': 'Myllynkatu', 'addr:postcode': '21280', 'addr:housenumber': '1'}
# {'name': 'Rosso', 'brand': 'Rosso', 'amenity': 'restaurant'}
# {'name': 'Obra Mexican Cantina', 'level': '1', 'amenity': 'restaurant', 'cuisine': 'mexican', 'addr:city': 'Raisio', 'addr:street': 'Myllynkatu', 'addr:postcode': '21280', 'addr:housenumber': '1'}
# {'name': 'Rapido', 'amenity': 'restaurant'}
# {'name': 'Pizzaline', 'amenity': 'restaurant', 'cuisine': 'pizza', 'addr:city': 'Raisio', 'addr:street': 'Voudinkatu', 'addr:country': 'FI', 'addr:postcode': '21200', 'addr:housenumber': '9'}
# {'name': 'Ravintola Kanari', 'amenity': 'restaurant', 'cuisine': 'pizza;kebab', 'addr:city': 'Raisio', 'addr:street': 'Kauppakuja', 'addr:country': 'FI', 'addr:postcode': '21200', 'addr:housenumber': '2'}
# {'name': 'Grilli Kivelä', 'amenity': 'restaurant', 'cuisine': 'burger', 'addr:city': 'Raisio', 'addr:street': 'Raisiontori', 'addr:country': 'FI', 'addr:postcode': '21200', 'opening_hours': 'Mo-Th 09:00-21:00; Fr 09:00-23:00; Sa 12:00-23:00; Su 12:00-20:00', 'addr:housenumber': '5'}
# {'name': 'Pancho Villa', 'amenity': 'restaurant', 'cuisine': 'mexican', 'addr:city': 'Raisio', 'addr:street': 'Raisiontori', 'addr:country': 'FI', 'addr:postcode': '21200', 'addr:housenumber': '7'}
# {'name': 'Sofram', 'amenity': 'restaurant', 'cuisine': 'pizza', 'opening_hours': 'Mo-Th 10:30-22:00'}
# {'name': 'Mei Cin Ti', 'amenity': 'restaurant', 'cuisine': 'chinese'}
# {'name': 'Sofram', 'phone': '+358 2 4373385', 'amenity': 'restaurant', 'cuisine': 'kebab;pizza', 'addr:street': 'Tasalanaukio', 'addr:postcode': '21200', 'addr:housenumber': '12'}
# {'name': 'Martinhovi', 'amenity': 'restaurant', 'website': 'https://www.martinhovi.fi/', 'addr:city': 'Raisio', 'addr:street': 'Martinkatu', 'addr:country': 'FI', 'addr:postcode': '21200', 'addr:housenumber': '6'}
# {'name': 'Center Kebab Pizzeria', 'amenity': 'restaurant', 'cuisine': 'kebab;pizza', 'addr:city': 'Raisio', 'addr:street': 'Purokatu', 'addr:postcode': '21200', 'addr:housenumber': '2'}
# {'name': 'Ravintola Jasmin', 'level': '1', 'amenity': 'restaurant', 'cuisine': 'kebab;pizza', 'name:fi': 'Ravintola Jasmin', 'toilets': 'yes', 'addr:city': 'Turku', 'addr:street': 'Ieskatu', 'addr:postcode': '20210', 'opening_hours': 'Mo-Th 10:00-22:00; Fr-Sa 10:00-24:00; Su 11:00-22:00; PH closed', 'addr:housenumber': '1'}
# {'name': 'Arina Ravintola', 'phone': '+358 44 7575 151', 'amenity': 'restaurant', 'cuisine': 'kebab;pizza', 'name:fi': 'Arina Ravintola', 'opening_hours': 'Mo-Th 10:00-21:00; Fr-Sa 10:00-22:00; Su 10:00-21:00'}
# {'name': 'Länsi kebab & pizzeria', 'phone': '+358451047779', 'amenity': 'restaurant', 'cuisine': 'pizza;kebab'}
# {'name': 'VG WOK Raunistula', 'email': 'info@vgwok.fi', 'phone': '0456651793', 'seats': 'yes', 'amenity': 'restaurant', 'cuisine': 'asian', 'name:en': 'VG Wok', 'name:fi': 'VG Wok', 'name:sv': 'VG Wok', 'website': 'https://www.vgwok.fi/', 'takeaway': 'yes', 'addr:city': 'Turku', 'diet:vegan': 'yes', 'addr:street': 'Rauninaukio', 'addr:postcode': '20300', 'opening_hours': 'Mo-Th 11:00-18:00; Sa, Su 12:00-20:00; Fr 11:00-20:00', 'diet:vegetarian': 'only', 'addr:housenumber': '10', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Villa-Barker', 'phone': '+358405122847', 'amenity': 'restaurant', 'website': 'https://www.villa-barker.fi', 'addr:city': 'Turku', 'addr:street': 'Raunistulantie', 'addr:postcode': '20300', 'opening_hours': 'Mo-Fr 11:00-14:00', 'addr:housenumber': '15'}
# {'name': 'Pizza Perez', 'amenity': 'restaurant', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Orikedon taverna', 'amenity': 'restaurant', 'cuisine': 'kebab;pizza;salad'}
# {'name': 'Rahtiksen messi', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Kärsämäentie', 'postal_code': '20810', 'addr:housenumber': '11'}
# {'name': 'KahviTella Avoin Yhtiö', 'amenity': 'restaurant'}
# {'name': 'Ruokakello', 'brand': 'Unica', 'lunch': 'yes', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/ruokakello/', 'delivery': 'no', 'operator': 'Unica', 'addr:street': 'Varusmestarintie', 'addr:housenumber': '26', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'IKEA Raisio', 'amenity': 'restaurant', 'website': 'https://www.ikea.com/fi/fi/store/raisio/restaurant', 'addr:city': 'Raisio', 'wheelchair': 'yes', 'addr:street': 'Itäniityntie', 'addr:postcode': '21280', 'opening_hours': 'Mo-Fr 09:45-20:00; Sa 09:45-19:30; Su 09:45-17:30', 'internet_access': 'no', 'addr:housenumber': '15'}
# {'name': 'Turku Café', 'amenity': 'restaurant'}
# {'name': 'Orikedon lounastupa', 'amenity': 'restaurant', 'name:en': 'Lunch Orikedon Lounastupa', 'addr:postcode': '20380'}
# {'name': 'Orikedon Lounas', 'email': 'orikedonlounasravintola@gmail.com', 'phone': '+358 41 364 9430', 'amenity': 'restaurant', 'website': 'https://www.orikedonlounas.fi', 'addr:postcode': '20380'}
# {'name': 'Shell HelmiSimpukka Turku Oriketo', 'amenity': 'restaurant', 'website': 'https://www.shellhelmisimpukka.fi/turku-oriketo', 'addr:city': 'Turku', 'addr:street': 'Vanha Tampereentie', 'addr:postcode': '20380', 'opening_hours': '24/7', 'addr:housenumber': '203'}
# {'name': 'Hallis Kebab & Pizzeria', 'amenity': 'restaurant', 'cuisine': 'kebab;pizza', 'addr:city': 'Turku', 'addr:street': 'Gregorius IX:n tie', 'addr:postcode': '20540', 'addr:housenumber': '8'}
# {'name': 'Herkkupiste lounas', 'amenity': 'restaurant'}
# {'name': 'Skanssinkulma', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Biolinja', 'addr:postcode': '20750', 'addr:housenumber': '20', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': "Luckiefun's Sushibuffet", 'amenity': 'restaurant', 'cuisine': 'sushi', 'addr:street': 'Skanssinkatu', 'self_service': 'yes', 'outdoor_seating': 'yes', 'addr:housenumber': '10'}
# {'name': 'Rax Golden Buffet', 'brand': 'Rax', 'level': '0', 'amenity': 'restaurant', 'opening_hours': 'Mo-Fr 11:00-21:00, Sa 11:00-19:00, Su 11:00-18:00', 'outdoor_seating': 'no'}
# {'name': 'Martina', 'level': '0', 'amenity': 'restaurant', 'opening_hours': 'Mo-Fr 11:00-21:00, Sa 11:00-19:00, Su 11:00-18:00'}
# {'name': 'Itsudemo', 'amenity': 'restaurant', 'cuisine': 'sushi', 'addr:city': 'Turku', 'addr:street': 'Skanssinkatu', 'addr:postcode': '20730', 'addr:housenumber': '10'}
# {'amenity': 'restaurant'}
# {'name': 'Sodexo Turun AMK Lemminkäisenkatu', 'brand': 'Sodexo', 'amenity': 'restaurant', 'website': 'https://www.sodexo.fi/ravintolat/turku/turun-amk-lemminkaisenkatu', 'wheelchair': 'yes'}
# {'name': 'Joukahainen', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Joukahaisenkatu', 'addr:postcode': '20520', 'addr:housenumber': '9'}
# {'name': 'Sodexo Old Mill', 'brand': 'Sodexo', 'amenity': 'restaurant'}
# {'name': 'Itäharjun ILO lounasravintola', 'amenity': 'restaurant', 'cuisine': 'pizza;kebab;buffet', 'smoking': 'outside', 'website': 'http://www.ilolounas.fi/', 'delivery': 'no', 'takeaway': 'yes', 'addr:city': 'Turku', 'addr:street': 'Kalevantie', 'addr:postcode': '20540', 'opening_hours': 'Mo-Su 10:00-21:00', 'outdoor_seating': 'yes', 'addr:housenumber': '25'}
# {'name': 'FC Kebab', 'amenity': 'restaurant', 'cuisine': 'pizza;kebab'}
# {'url': 'http://www.nummispizzeria.fi/', 'name': 'Nummis Kebab & Pizzeria', 'amenity': 'restaurant', 'cuisine': 'kebab;pizza', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Pizzeria Ali Baba', 'amenity': 'restaurant', 'cuisine': 'pizza;kebab', 'wheelchair': 'yes'}
# {'name': "O'Learys", 'level': '1', 'amenity': 'restaurant', 'website': 'https://olearys.fi/turku-holiday-club-caribia/', 'diet:vegan': 'yes', 'diet:vegetarian': 'yes'}
# {'url': 'http://www.classicpizza.fi/ravintola/caribia-turku/', 'name': 'Classic Pizza Caribia', 'level': '-1', 'amenity': 'restaurant', 'cuisine': 'pizza', 'smoking': 'no', 'operator': 'Classic Pizza', 'addr:city': 'Turku', 'addr:street': 'Kongressikuja', 'addr:postcode': '20540', 'opening_hours': 'Mo-Sa 12:00-22:00; Su 12:00-20:00; PH unknown', 'addr:housenumber': '1'}
# {'name': 'Bruukki', 'email': 'info@bruukki.fi', 'lunch': 'yes', 'phone': '+358207417331', 'amenity': 'restaurant', 'website': 'https://www.bruukki.fi/', 'payment:edenred_card': 'yes'}
# {'name': 'Macciavelli', 'brand': 'Unica', 'email': 'macciavelli@unica.fi', 'level': '0', 'lunch': 'yes', 'phone': '040 480 8957', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/macciavelli/', 'delivery': 'no', 'operator': 'Unica', 'takeaway': 'yes', 'addr:city': 'Turku', 'wheelchair': 'yes', 'addr:street': 'Assistentinkatu', 'addr:postcode': '20014', 'opening_hours': 'Mo-Th 08:00-17:00; Fr 08:00-16:00; Mo-Th 10:30-16:30 "lunch"; Fr 10:30-16:00 "lunch"', 'diet:vegetarian': 'yes', 'addr:housenumber': '5', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'Piccu Maccia', 'brand': 'Unica', 'email': 'macciavelli@unica.fi', 'level': '0', 'lunch': 'yes', 'phone': '040 4808 957', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'https://www.piccumaccia.fi/', 'delivery': 'no', 'operator': 'Unica', 'addr:city': 'Turku', 'diet:vegan': 'yes', 'wheelchair': 'yes', 'addr:street': 'Assistentinkatu', 'description': 'Avoinna:\n\nma-ti 10.30-14.00\nke-pe 10.30-22.00.\nla 12.00-22.00.\n\nLounas\nma-pe 11-14\nla 12-15', 'addr:postcode': '20500', 'diet:vegetarian': 'yes', 'addr:housenumber': '5', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes'}
# {'cafe': 'yes', 'name': 'Galilei', 'brand': 'Unica', 'email': 'galilei@unica.fi', 'level': '0', 'lunch': 'yes', 'phone': '+358 40 0169161', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/galilei/', 'delivery': 'no', 'operator': 'Unica', 'addr:city': 'Turku', 'wheelchair': 'yes', 'addr:street': 'Vesilinnantie', 'addr:postcode': '20500', 'diet:vegetarian': 'yes', 'addr:housenumber': '3', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes', 'opening_hours:covid19': 'off'}
# {'name': 'Cafe Arcanum', 'brand': 'Unica', 'lunch': 'yes', 'amenity': 'restaurant', 'smoking': 'no', 'delivery': 'no', 'operator': 'Unica', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'Café Fänriken', 'phone': '+358 2 215 3705', 'amenity': 'restaurant', 'website': 'http://www.studentlunch.fi/se/restauranger-och-cafeer/fanriken', 'addr:city': 'Turku', 'addr:street': 'Vänrikinkatu', 'opening_hours': 'Mo-Th 08:00-15:00; Fr 08:00-14:30', 'addr:housenumber': '3', 'discount:students': 'yes'}
# {'name': 'Café Gadolinia', 'phone': '+358 2 215 3700', 'amenity': 'restaurant', 'website': 'http://www.studentlunch.fi/se/restauranger-och-cafeer/gado', 'addr:city': 'Turku', 'addr:street': 'Porthansgatan', 'opening_hours': 'Mo-Th 08:00-19:00; Fr 08:00-15:15', 'addr:housenumber': '3–5', 'discount:students': 'yes'}
# {'name': 'VG Wok', 'phone': '+358 46 8411 207', 'amenity': 'restaurant', 'cuisine': 'vietnamese;thai', 'website': 'https://www.vgwok.fi/', 'addr:city': 'Turku', 'diet:vegan': 'yes', 'addr:street': 'Hämeenkatu', 'addr:postcode': '20500', 'opening_hours': 'Mo off; Tu-Fr 11:00-18:00; Sa-Su 12:00-19:00', 'diet:vegetarian': 'yes', 'addr:housenumber': '1'}
# {'name': 'Pronto', 'amenity': 'restaurant', 'cuisine': 'pizza;kebab', 'opening_hours': 'Mo-We 10:30-21:00, Th 10:30-23:00, Fr 10:30-04:00, Sa 12:00-04:00, Su 12:00-21:00', 'diet:vegetarian': 'yes'}
# {'name': 'Brygge', 'brand': 'Unica', 'email': 'assarinullakko@unica.fi', 'level': '1', 'lunch': 'yes', 'phone': '0400 268788', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/brygge/', 'delivery': 'no', 'operator': 'Unica', 'addr:city': 'Turku', 'addr:unit': 'A', 'diet:vegan': 'yes', 'wheelchair': 'limited', 'addr:street': 'Rehtorinpellonkatu', 'description': 'Avoinna\n\nma-pe 10.30-18\n\nKasvis- ja vegaaniravintola. Avoinna kaikille asiakkaille (opiskelijahintaista ruokaa opiskelijoille).\n\nOpen for anyone (student prices apply).', 'addr:postcode': '20500', 'diet:vegetarian': 'yes', 'addr:housenumber': '4', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'Assarin ullakko', 'brand': 'Unica', 'email': 'assarinullakko@unica.fi', 'level': '1', 'lunch': 'yes', 'phone': '0400 268 788', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/assarin-ullakko/', 'delivery': 'no', 'operator': 'Unica', 'addr:city': 'Turku', 'addr:unit': 'A', 'addr:street': 'Rehtorinpellonkatu', 'description': 'Avoinna (Lounas koko aukioloajan):\n\nma-pe 10.30-20.00.\n\nLa\n10.00-18.00.\n\nSu\n11.30-16.30.\n\nAvoin kaikille asiakkaille (opiskelijahintaista ruokaa opiskelijoille).\n\nOpen for anyone (student prices apply).', 'addr:postcode': '20500', 'diet:vegetarian': 'yes', 'addr:housenumber': '4', 'takeaway:covid19': 'yes', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Monttu', 'email': 'monttu@juvenes.fi', 'lunch': 'yes', 'phone': '+358 207 600 130', 'amenity': 'restaurant', 'website': 'https://www.juvenes.fi/monttu', 'operator': 'Juvenes', 'opening_hours': 'Mo-Th 10:30-15:00; Fr 10:30-14:00', 'discount:students': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'Bistro Elli', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Joukahaisenkatu', 'addr:housenumber': '6'}
# {'name': 'Flavoria', 'brand': 'Sodexo', 'email': 'medisiina.fms.fi@sodexo.com', 'lunch': 'yes', 'phone': '+358504358013', 'amenity': 'restaurant', 'website': 'https://www.sodexo.fi/flavoria', 'opening_hours': 'Mo-Th 07:45-17:00; Fr 07:45-16:00', 'brand:wikidata': 'Q1475554', 'brand:wikipedia': 'fi:Sodexo', 'discount:students': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'VG Wok', 'amenity': 'restaurant', 'name:en': 'VG Wok', 'name:fi': 'VG Wok', 'name:sv': 'VG Wok', 'website': 'http://vg-wok.com', 'addr:city': 'Turku', 'addr:street': 'Tykistökatu', 'opening_hours': 'Mo-Th 11:00-18:00; Fr 11:00-20:00; Sa-Su 12:00-20:00', 'addr:housenumber': '6'}
# {'name': 'Dental', 'brand': 'Unica', 'email': 'dental@unica.fi', 'level': '1', 'lunch': 'Mo-Fr 10:00-14:00', 'phone': '040 548 9093', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/dental/', 'delivery': 'no', 'operator': 'Unica', 'addr:city': 'Turku', 'wheelchair': 'yes', 'addr:street': 'Lemminkäisenkatu', 'addr:postcode': '20520', 'opening_hours': 'Mo-Fr 07:45-14:00', 'diet:vegetarian': 'yes', 'addr:housenumber': '2', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'Athene', 'amenity': 'restaurant', 'cuisine': 'greek'}
# {'name': 'Deli Pharma', 'brand': 'Unica', 'email': 'delica@unica.fi', 'level': '0', 'lunch': 'yes', 'phone': '040 480 8956', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/deli-pharma/', 'delivery': 'no', 'operator': 'Unica', 'addr:city': 'Turku', 'diet:vegan': 'yes', 'wheelchair': 'yes', 'addr:street': 'Itäinen Pitkäkatu', 'description': 'Avoinna:\n\nAamiainen Deli Pharmassa 8-9.30.\n\nDeli Pharma\nma-pe 10.45-14.00\n\nAvoin kaikille asiakkaille (opiskelijahintaista ruokaa opiskelijoille).\n\nOpen for anyone (student prices apply).', 'addr:postcode': '20520', 'diet:vegetarian': 'yes', 'addr:housenumber': '4', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'Kado Sushi Bar', 'amenity': 'restaurant', 'cuisine': 'sushi', 'addr:city': 'Turku', 'addr:street': 'Itäinen Pitkäkatu', 'addr:postcode': '20520', 'addr:housenumber': '4'}
# {'name': 'Delica', 'brand': 'Unica', 'email': 'delica@unica.fi', 'level': '0', 'lunch': 'yes', 'phone': '040 480 8956', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/delica/', 'delivery': 'no', 'operator': 'Unica', 'addr:city': 'Turku', 'wheelchair': 'yes', 'addr:street': 'Itäinen Pitkäkatu', 'description': 'Avoinna:\n\nma-pe \n10.15-14.30 \n\nAamiainen Deli Pharman puolella klo 8-9.30\n\nAvoin kaikille asiakkaille (opiskelijahintaista ruokaa opiskelijoille).\n\nOpen for anyone (student prices apply).', 'addr:postcode': '20520', 'diet:vegetarian': 'yes', 'addr:housenumber': '4', 'discount:students': 'yes', 'payment:contactless': 'yes', 'payment:edenred_card': 'yes'}
# {'name': 'Amica Snack City', 'brand': 'Amica', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Lemminkäisenkatu', 'addr:postcode': '20520', 'addr:housenumber': '14-18'}
# {'name': 'Linus', 'brand': 'Unica', 'email': 'linus@unica.fi', 'level': '0', 'phone': '040 1970 559', 'amenity': 'restaurant', 'smoking': 'no', 'website': 'http://www.unica.fi/fi/ravintolat/linus/', 'addr:city': 'Turku', 'diet:vegan': 'yes', 'wheelchair': 'yes', 'addr:street': 'Joukahaisenkatu', 'description': 'Avoinna:\n\nma - to 7.30-17.15\npe 7.30-15\n\nLounas:\nma - pe 10.30-14.30\n\nAvoin kaikille asiakkaille (opiskelijahintaista ruokaa opiskelijoille).\n\nOpen for anyone (student prices apply).', 'addr:postcode': '20500', 'diet:vegetarian': 'yes', 'addr:housenumber': '3', 'discount:students': 'yes'}
# {'name': 'Mauno BioCity', 'phone': '+358503364819', 'amenity': 'restaurant', 'website': 'https://www.mauno.fi/', 'addr:city': 'Turku', 'addr:street': 'Tykistökatu', 'addr:postcode': '20520', 'addr:housenumber': '6', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'amenity': 'restaurant'}
# {'name': 'Kisälli lounasravintola', 'brand': 'Unica', 'email': 'kisalli@unica.fi', 'lunch': 'yes', 'phone': '+358 40 188 3839', 'amenity': 'restaurant', 'name:en': 'Lunch Restaurant Kisälli', 'website': 'https://www.unica.fi/ravintolat/Kupittaa/kisalli/', 'addr:city': 'Turku', 'addr:street': 'Joukahaisenkatu', 'description': 'Viikon lounaslista netissä. Opiskelijahintaista ruokaa opiskelijakortilla!\n\nSee weekly lunch menu from website. We have student-priced food for all discount-applicable students!', 'addr:postcode': '20520', 'addr:housenumber': '7', 'discount:students': 'yes'}
# {'name': 'Kaivomestari', 'brand': 'Unica', 'lunch': 'yes', 'amenity': 'restaurant', 'cuisine': 'deli', 'addr:city': 'Turku', 'addr:street': 'Joukahaisenkatu', 'addr:housenumber': '7', 'discount:students': 'no'}
# {'name': 'China Jade', 'amenity': 'restaurant', 'cuisine': 'chinese', 'website': 'http://www.ravintolachinajade.com/', 'addr:city': 'Turku', 'addr:street': 'Lemminkäisenkatu', 'addr:postcode': '20520', 'addr:housenumber': '14'}
# {'name': 'Turun Upseerikerho', 'amenity': 'restaurant'}
# {'name': 'Kiinan muuri', 'amenity': 'restaurant', 'cuisine': 'chinese'}
# {'name': 'Splizzeria', 'phone': '043 825 8804', 'amenity': 'restaurant', 'website': 'https://splizzeria.fi/', 'addr:street': 'Kiinanmyllynkatu', 'opening_hours': 'Mo-Fr 10:30-22:00; Sa, Su 12:00-22:00', 'addr:housenumber': '5A'}
# {'name': 'Fiilis Cafe & Bistro', 'phone': '+358438258804', 'amenity': 'restaurant', 'website': 'https://cafefiilis.fi/', 'addr:city': 'Turku', 'addr:street': 'Kiinamyllynkatu', 'addr:postcode': '20500', 'addr:housenumber': '5 A'}
# {'url': 'http://www.subway.fi/fi/ravintolat/turku/hameenkatu/', 'name': 'Subway', 'amenity': 'restaurant', 'operator': 'Subway', 'diet:vegan': 'yes', 'addr:street': 'Hämeenkatu', 'opening_hours': '24/7', 'diet:vegetarian': 'yes', 'addr:housenumber': '7'}
# {'name': 'Delhi Darbar', 'amenity': 'restaurant', 'cuisine': 'indian', 'website': 'https://www.delhidarbar.fi/', 'addr:street': 'Hämeenkatu', 'addr:housenumber': '8', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Ravintola Kuori', 'phone': '+358 20 794 0330', 'amenity': 'restaurant', 'name:en': 'Kuori Food & Wine', 'website': 'https://www.ravintolakuori.fi/', 'addr:city': 'Turku', 'ref:vatin': 'FI-27707532', 'diet:vegan': 'yes', 'addr:street': 'Hämeenkatu', 'addr:postcode': '20500', 'opening_hours': 'Tu-Fr 11:00-14:00; Th-Fr 17:00-23:00; Sa 15:00-23:00', 'diet:vegetarian': 'only', 'addr:housenumber': '8', 'opening_hours:covid19': 'same'}
# {'name': 'Zhong Hua', 'amenity': 'restaurant', 'cuisine': 'chinese', 'addr:street': 'Hämeenkatu', 'addr:housenumber': '10'}
# {'url': 'http://www.thairavintola.com/', 'name': 'Ravintola Thai Nong Khai', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Hovioikeudenkatu', 'addr:postcode': '20500', 'addr:housenumber': '2'}
# {'name': 'Yangtze', 'amenity': 'restaurant', 'cuisine': 'chinese'}
# {'name': 'Trattoria Romana', 'amenity': 'restaurant', 'opening_hours': 'Tu-Fr 11:00-23:00, Sa 13:00-23:00, Su 13:00-20:00', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Kimi Sushi', 'amenity': 'restaurant'}
# {'name': 'Roster', 'amenity': 'restaurant', 'opening_hours': 'Sa 15:00-22:00; Mo-Th 11:00-14:00, 16:00-21:30; Fr 11:00-14:00, 16:00-22:00'}
# {'name': 'Teini', 'amenity': 'restaurant', 'postal_code': '20500', 'addr:housenumber': '1'}
# {'url': 'http://gustavo.fi/en/', 'name': 'Restaurant Gustavo', 'amenity': 'restaurant', 'postal_code': '20100', 'opening_hours': 'Tu-Fr 11:00-14:00,17:00-23:00, Sa 15:00-23:00', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'ref': '3', 'name': 'Panini Caffé Ristorante', 'phone': '+358 2 251 5310', 'amenity': 'restaurant', 'website': 'ravintolapanini.fi', 'addr:city': 'Turku', 'addr:street': 'Linnankatu', 'postal_code': '20100', 'addr:postcode': '20100', 'opening_hours': 'Mo-Fr 11:00-14:00, 16:30-22:00; Sa 12:00-22:00', 'addr:housenumber': '3', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Tiirikkala', 'email': 'info@tiirikkala.fi', 'phone': '+358 20 741 7337', 'amenity': 'restaurant', 'website': 'https://www.tiirikkala.fi/', 'addr:city': 'Turku', 'addr:street': 'Linnankatu', 'addr:postcode': '20100', 'opening_hours': 'Mo-Th 11:00-22:00, Fr 11:00-23:00, Sa 12:00-23:00, Su 12:00-20:00', 'addr:housenumber': '3'}
# {'ref': '3', 'url': 'http://www.mami.fi/', 'name': 'Mami', 'phone': '+35822311111', 'amenity': 'restaurant', 'website': 'https://www.mami.fi', 'postal_code': '20100', 'opening_hours': 'Tu-Fr 11:00-15:00, 16:30-22:00, Sa 13:00-22:00', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Söör mixalåt', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Eerikinkatu', 'addr:housenumber': '7b'}
# {'amenity': 'restaurant'}
# {'name': 'Bagel House', 'email': 'info@bagelhouse.fi', 'phone': '+358 40 8085474', 'amenity': 'restaurant', 'website': 'https://www.bagelhouse.fi', 'addr:city': 'Turku', 'addr:street': 'Brahenkatu', 'addr:country': 'FI', 'addr:postcode': '20100', 'opening_hours': 'Mo-Fr 10:00-19:00; Sa 11:00-17:00', 'addr:housenumber': '2'}
# {'ref': '3A', 'url': 'http://www.linnankatu3.fi/', 'name': 'Tårget', 'phone': '+35822339279', 'amenity': 'restaurant', 'website': 'https://www.matbar.fi/', 'addr:city': 'Turku', 'addr:unit': 'A', 'addr:street': 'Linnankatu', 'postal_code': '20100', 'addr:postcode': '20100', 'opening_hours': 'Mo-Th 11:00-22:00, Fr 11:00-02:00, Sa 12:00-02:00', 'addr:housenumber': '3'}
# {'name': 'Hügge', 'amenity': 'restaurant', 'cuisine': 'vege', 'website': 'https://hugge.fi/', 'diet:vegan': 'yes', 'opening_hours': 'Mo-Th 11-22:00 Fri 11-1:00 Sat 12-1:00', 'diet:vegetarian': 'only'}
# {'name': 'Ravintola Smör', 'phone': '025369444', 'amenity': 'restaurant', 'website': 'https://www.smor.fi/', 'addr:street': 'Läntinen rantakatu', 'opening_hours': 'Mo-Fr 11:00-14:00, 16:30-23:00; Sa 16:00-23:00', 'addr:housenumber': '3', 'opening_hours:covid19': 'off'}
# {'name': 'China & Thai Palace', 'amenity': 'restaurant', 'opening_hours': 'Mo-Fr 11:00-21:00; Sa 12:00-21:00; Su 12:00-19:00'}
# {'name': 'E.Ekblom', 'amenity': 'restaurant', 'addr:street': 'Kauppiaskatu', 'opening_hours': 'Tu-Th 17:00-23:00; Fr 16:00-23:00; Sa 14:00-23:00', 'addr:housenumber': '1', 'opening_hours:covid19': 'off'}
# {'url': 'http://www.karen.abo.fi/lunch/klubb/', 'name': 'Kåren', 'amenity': 'restaurant', 'website': 'http://karen.fi/', 'addr:city': 'Turku', 'addr:street': 'Hämeenkatu', 'postal_code': '20500', 'addr:postcode': '20500', 'addr:housenumber': '22', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Kasvisravintola Keidas', 'amenity': 'restaurant', 'diet:vegan': 'yes', 'diet:vegetarian': 'yes'}
# {'name': 'Ravintola Kiinanmuuri', 'amenity': 'restaurant', 'cuisine': 'kiinalainen'}
# {'url': 'http://www.chinamarket.fi/kiinanmuuri/', 'name': 'Kiinanmuuri', 'amenity': 'restaurant'}
# {'name': 'Kaskis', 'amenity': 'restaurant', 'website': 'https://kaskis.fi', 'wikidata': 'Q56401113', 'addr:city': 'Turku', 'wikipedia': 'fi:Kaskis', 'addr:street': 'Kaskenkatu', 'addr:postcode': '20700', 'addr:housenumber': '6a'}
# {'name': 'Vietnamilainen Ravintola Kim', 'amenity': 'restaurant'}
# {'name': 'Vietnamilainen ravintola Kim', 'phone': '+358 40 5771358', 'amenity': 'restaurant', 'website': 'https://www.facebook.com/VietnamilainenRavintolaKim/', 'addr:city': 'Turku', 'addr:street': 'Kaskenkatu', 'addr:postcode': '20700', 'addr:housenumber': '8', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Laivaravintola Svarte Rudolf', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Itäinen Rantakatu', 'addr:housenumber': '13', 'opening_hours:covid19': 'off'}
# {'name': 'Pub Niska', 'phone': '+358407391006', 'amenity': 'restaurant', 'website': 'https://www.niskaturku.com/', 'delivery': 'yes', 'takeaway': 'yes', 'addr:city': 'Turku', 'addr:street': 'Kristiinankatu', 'addr:postcode': '20100', 'opening_hours': 'Mo-Th 11:00-20:00; Fr 11:00-23:00; Sa 12:00-23:00; Su 12:00-21:00', 'addr:housenumber': '1', 'opening_hours:covid19': 'same'}
# {'name': 'Aitiopaikka', 'email': 'aitiopaikka@frescoravintolat.fi', 'phone': '+358 400 176 481', 'amenity': 'restaurant', 'website': 'https://www.frescoravintolat.fi/?sivut/lounas_aitiopaikka.html', 'operator': 'FresCo Ravintolat Oy', 'opening_hours': 'Mo-Fr 07:45-14:30'}
# {'name': "Sergio's", 'amenity': 'restaurant', 'cuisine': 'italian', 'website': 'https://www.sergio.fi/', 'opening_hours': 'Mo-Fr 16:00-23:00; Sa 13:00-23:00', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Teatteriravintola Kivi', 'phone': '+358 50 5949946', 'amenity': 'restaurant', 'website': 'https://www.teatteriravintolakivi.fi/', 'addr:city': 'Turku', 'addr:street': 'Itäinen Rantakatu', 'addr:postcode': '20800', 'addr:housenumber': '14'}
# {'name': 'Tsing-Tao 青岛酒楼', 'phone': '046 8121189', 'amenity': 'restaurant', 'cuisine': 'chinese', 'website': 'https://ravintolatsingtao.com/', 'addr:city': 'Turku', 'addr:country': 'FI'}
# {'name': 'Sevilla', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:street': 'Humalistonkatu', 'addr:country': 'FI', 'addr:postcode': '20100', 'addr:housenumber': '2'}
# {'url': 'http://www.yasukonkeittio.com/', 'name': 'Yasukon Keittiö', 'amenity': 'restaurant', 'cuisine': 'japanese', 'opening_hours': 'Mo-Fr 12:00-18:00; Sa 12:00-17:00'}
# {'name': 'RIONI', 'amenity': 'restaurant', 'cuisine': 'georgian', 'website': 'http://www.rioni.fi', 'addr:city': 'Turku', 'addr:street': 'Kristiinankatu', 'addr:postcode': '20100', 'access:covid19': 'no', 'addr:housenumber': '9', 'delivery:covid19': 'yes', 'takeaway:covid19': 'yes', 'drive_through:covid19': 'no', 'opening_hours:covid19': 'open'}
# {'name': 'Hanko Sushi', 'amenity': 'restaurant', 'cuisine': 'sushi', 'opening_hours': 'Mo-Th 11:00-21:00, Fr 11:00-22:00, Sa 12:00-22:00, Su 13:00-20:00'}
# {'url': 'http://www.sikhar.fi/', 'name': 'Ravintola Sikhar', 'amenity': 'restaurant', 'cuisine': 'nepalese', 'website': 'http://www.sikhar.fi/', 'addr:city': 'Turku', 'wheelchair': 'limited', 'addr:street': 'Kristiinankatu', 'opening_hours': 'Mo-Th 11:00-21:00, Fr 11:00-22:00, Sa 12:00-22:00, Su 12:00-21:00'}
# {'name': 'Taco Bell', 'amenity': 'restaurant', 'addr:city': 'Turku', 'addr:country': 'FI'}
# {'url': 'http://www.panimoravintolakoulu.fi', 'name': 'Panimoravintola Koulu', 'amenity': 'restaurant', 'wikidata': 'Q7131168', 'addr:city': 'Turku', 'wheelchair': 'yes', 'addr:country': 'FI', 'microbrewery': 'yes', 'opening_hours:covid19': 'off'}
# {'name': 'Nomad Food and Wine', 'phone': '+358 40 3602166', 'amenity': 'restaurant', 'website': 'https://www.nomadfoodandwine.com/', 'addr:city': 'Turku', 'addr:street': 'Kristiinankatu', 'addr:postcode': '20100', 'addr:housenumber': '5', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Aune', 'email': 'aune@ravintolaaune.fi', 'phone': '+358 44 776 0660', 'amenity': 'restaurant', 'website': 'https://ravintolaaune.fi/', 'opening_hours': 'Mo-Th 16:00-00:00; Fr 16:00-02:00; Sa 14:00-02:00; Su 14:00-00:00'}
# {'name': 'Ravintola Julinia', 'amenity': 'restaurant', 'website': 'https://www.ravintolajulinia.fi/', 'addr:postcode': '20100', 'opening_hours': 'Mo-Fr 11:00-15:00; Sa 12:00-16:00; Su 12:00-15:00', 'addr:housenumber': '18', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Kellariravintola', 'amenity': 'restaurant', 'opening_hours': 'Mo 11:00-15:00; Tu-Fr 11:00-22:00; Sa 12:00-22:00; Su 12:00-18:00'}
# {'name': 'Pizzeria Dennis', 'amenity': 'restaurant', 'cuisine': 'pizza', 'website': 'https://www.dennis.fi/', 'delivery': 'yes', 'addr:postcode': '20100', 'opening_hours': 'Mo-Th 11:00-19:00; Fr 11:00-21:00; Sa 12:00-20:00', 'access:covid19': 'no', 'addr:housenumber': '17', 'delivery:covid19': 'yes', 'takeaway:covid19': 'yes', 'drive_through:covid19': 'no', 'opening_hours:covid19': 'Mo-Th 11:00-19:00; Sa 12:00-20:00'}
# {'name': 'Ludu', 'phone': '+358 20 734 0310', 'amenity': 'restaurant', 'website': 'https://ludu.fi/', 'takeaway': 'no', 'addr:city': 'Turku', 'addr:street': 'Linnankatu', 'addr:postcode': '20100', 'opening_hours': 'Tu-Fr 11:00-14:00; Tu-Sa 17:00-23:00', 'addr:housenumber': '17', 'opening_hours:covid19': 'off'}
# {'name': 'Hallin kotikokki', 'phone': '+358443270455', 'amenity': 'restaurant', 'website': 'https://hallinkotikokki.fi', 'addr:city': 'Turku', 'addr:street': 'Eerikinkatu', 'description': 'COVID-19: HUOM!! Nyt vallitsevan poikkeustilan johdosta meiltä saa tilattua ruokaa mukaan vietäväksi. Toimitamme ruoan myös drive-in tyyppisesti autollesi Kauppahallin parkkipaikalle ja laskutus hoituu kätevästi kortilla. Soita meille ja tilaa yksi tai', 'addr:postcode': '20100', 'addr:housenumber': '16', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# ...
# {'name': 'Pancho Villa', 'amenity': 'restaurant', 'cuisine': 'tex-mex', 'wikidata': 'Q18586412'}
# {'name': 'Raahen Pizza & Kebab', 'phone': '+358 40 0227888', 'amenity': 'restaurant', 'cuisine': 'pizza', 'opening_hours': 'Fr,Sa 20:00-04:30'}
# {'name': 'Bright Sushi', 'phone': '+358 46 588 8712', 'amenity': 'restaurant', 'cuisine': 'chinese', 'old_name': 'Chang Xing', 'addr:city': 'Raahe', 'addr:street': 'Laivurinkatu', 'addr:postcode': '92100', 'opening_hours': 'Mo-Fr 10:30-21:00; Sa,Su 11:30-21:00', 'addr:housenumber': '11'}
# {'name': 'Hai Long', 'amenity': 'restaurant', 'cuisine': 'chinese', 'takeaway': 'no'}
# {'name': 'Pizzeria Alto Mare', 'amenity': 'restaurant', 'cuisine': 'pizza', 'website': 'www.altomare.fi', 'addr:city': 'Raahe', 'addr:street': 'Kirkkokatu', 'addr:postcode': '92100', 'addr:housenumber': '35'}
# {'name': 'Ravintola Dado', 'amenity': 'restaurant', 'website': 'http://www.dado.ws'}
# {'amenity': 'restaurant'}
# {'name': 'CakePop Oy Lohenpyrstö', 'amenity': 'restaurant', 'opening_hours': 'Tu-Fr 10:00-18:00, Sa-Su 12:00-18:00; Sa 08:00-12:00'}
# {'name': 'Meripirtti', 'phone': '+358-40-552-8235', 'amenity': 'restaurant', 'opening_hours': 'for requests only', 'addr:housenumber': '64'}
# {'name': 'DiMare pizzeria-ravintola', 'amenity': 'restaurant'}
# {'name': 'Ravintola Pursiseura', 'amenity': 'restaurant'}
# {'name': 'Sataman Tähti', 'amenity': 'restaurant', 'addr:city': 'Kemi', 'addr:street': 'Luulajantie', 'addr:postcode': '94100', 'addr:housenumber': '7'}
# {'name': 'Ravintola Melissa', 'amenity': 'restaurant', 'wheelchair': 'yes'}
# {'name': 'Pizzeria Captain', 'phone': '+35816221751', 'amenity': 'restaurant', 'cuisine': 'kebab;pizza', 'addr:street': 'Keskuspuistokatu', 'addr:postcode': '94100', 'opening_hours': 'Su 12:00-22:00; Mo-Th 11:00-22:00; Fr-Sa 11:00-04:30', 'addr:housenumber': '17'}
# {'name': 'Nimbus', 'amenity': 'restaurant'}
# {'name': 'Pulla-Jussi', 'amenity': 'restaurant'}
# {'name': 'Savotan Sanni', 'amenity': 'restaurant'}
# {'bar': 'yes', 'name': 'Hillen Helmi, Hämylä, Hillen Grilli', 'amenity': 'restaurant', 'cuisine': 'pizza;burger;kebab', 'website': 'https://www.facebook.com/hillenhelmi/', 'fast_food': 'yes'}
# {'bar': 'no', 'name': 'Ravintola Mori', 'amenity': 'restaurant', 'cuisine': 'pizza;burger;kebab', 'website': 'http://www.ravintolamori.fi/', 'fast_food': 'yes'}
# {'name': 'Neste Tupasvilla', 'amenity': 'restaurant', 'website': 'https://www.neste.fi/asema/neste-keminmaa-tupasvilla', 'snowmobile': 'yes', 'was:website': 'http://www.neste.fi/hakuasema.aspx?id=594'}
# {'name': 'Neste Lapintuuli', 'amenity': 'restaurant', 'website': 'http://www.liikenneasema.k-market.fi/kaupat/lapintuuli/', 'snowmobile': 'yes'}
# {'amenity': 'restaurant'}
# {'name': 'Merihelmi', 'amenity': 'restaurant', 'website': 'http://www.rynkynranta.com', 'snowmobile': 'yes'}
# {'name': 'Nelosparkki, Neste Kuivaniemi', 'amenity': 'restaurant', 'website': 'https://www.nelosparkki.fi/', 'snowmobile': 'yes', 'was:website': 'www.facebook.com/Nelosparkki/', 'outdoor_seating': 'yes'}
# {'name': 'Makumanni', 'phone': '+358-16-447-810', 'amenity': 'restaurant', 'cuisine': 'regional', 'opening_hours': 'Mo-Fr 07:00-17:00; Sa 10:00-15:00'}
# {'name': 'Ravintola Pappilan Pehtoori', 'amenity': 'restaurant', 'website': 'http://www.tasocatering.com/'}
# {'name': 'Kievari', 'amenity': 'restaurant', 'addr:city': 'Kuivaniemi', 'addr:street': 'Lohitie', 'addr:postcode': '95100', 'addr:housenumber': '2'}
# {'name': 'Mäkipeura', 'amenity': 'restaurant', 'website': 'http://www.makipeura.fi', 'snowmobile': 'yes'}
# {'name': 'Rieskapaikka', 'shop': 'bakery', 'amenity': 'restaurant', 'website': 'http://www.rieskapaikka.fi/', 'snowmobile': 'yes'}
# {'name': 'Lähi-ABC Tornio', 'amenity': 'restaurant', 'website': 'https://www.abcasemat.fi/fi/asemat/lahi-abc-tornio', 'opening_hours': 'Mo-Sa 06:00-24:00, Su 08:00-22:00'}
# {'name': 'Neste K Tornio Röyttäntie', 'amenity': 'restaurant', 'website': 'https://www.neste.fi/asema/neste-k-tornio-royttantie', 'snowmobile': 'yes'}
# {'name': 'Mustaparran päämaja', 'phone': '+358 40 1260222', 'amenity': 'restaurant', 'addr:city': 'Tornio', 'addr:street': 'Hallituskatu', 'addr:postcode': '95400', 'opening_hours': 'Mo-Th 11:00-21:00; Fr 11:00-22:00; Sa 12:00-22:00; Su 13:00-18:00', 'addr:housenumber': '6'}
# {'name': 'Ararat', 'amenity': 'restaurant', 'cuisine': 'pizza', 'opening_hours': 'Mo-Fr 10:30-22:00; Sa-Su 11:00-22:00', 'addr:housenumber': '11'}
# {'name': 'Ravintola Pirttihirmu', 'phone': '+358447272154', 'amenity': 'restaurant', 'website': 'https://www.facebook.com/ravintolapirttihirmu/', 'addr:city': 'Tornio', 'addr:street': 'Vesaisenkatu', 'addr:postcode': '95400', 'opening_hours': 'Mo 10:30-19:30; Sa,Su 11:00-18:30', 'addr:housenumber': '1', 'takeaway:covid19': 'yes', 'opening_hours:covid19': 'open'}
# {'name': 'Kerhoravintola', 'amenity': 'restaurant', 'cuisine': 'regional'}
# {'name': 'Saigon', 'amenity': 'restaurant', 'cuisine': 'vietnamese;pizza', 'opening_hours': 'Mo 10:30-19:00, Tu-Fr 10:30-22:00; Sa-Su 12:00-22:00'}
# {'name': 'Dimare', 'amenity': 'restaurant', 'cuisine': 'pizza;kebab', 'opening_hours': 'Mo-Fr 10:30-22:00; Sa 11:00-22:00, Su 12:00-22:00'}
# {'name': 'Kisälli', 'phone': '+358-10-383-4491', 'amenity': 'restaurant', 'cuisine': 'regional', 'addr:street': 'Urheilukatu', 'opening_hours': 'Mo-Fr 11:00-13:00', 'addr:housenumber': '6'}
# {'name': 'Pitoporras', 'phone': '+358-16-481-341', 'amenity': 'restaurant', 'cuisine': 'regional', 'website': 'http://www.pitoporras.fi/', 'old_name': 'City-Baari', 'addr:street': 'Satamakatu', 'opening_hours': 'Mo-Fr 10:30-14:30', 'addr:housenumber': '4'}
# {'name': 'Golden Flower', 'phone': '+358-16-481-384', 'amenity': 'restaurant', 'cuisine': 'chinese;pizza', 'website': 'http://www.goldenflower.fi/', 'loc_name': 'Kiinalainen', 'opening_hours': 'Mo 11:00-20:00; Tu-Fr 11:00-22:00; Sa 12:00-22:00; Su 12:00-21:00', 'addr:housenumber': '8'}
# {'amenity': 'restaurant', 'cuisine': 'regional', 'outdoor_seating': 'yes'}
# {'name': 'Siikakartano', 'phone': '+358-40-755-1858', 'amenity': 'restaurant', 'cuisine': 'regional', 'addr:housenumber': '130'}
# {'name': 'Ravintola Pikku-Kultamaa ent Tuulan Kahvila', 'owner': 'Kilpisjärven Lomakeskus Oy', 'phone': '+358 400 396 684', 'amenity': 'restaurant', 'building': 'yes', 'was:phone': '+35816539229'}
# {'name': 'Rajabaari', 'amenity': 'restaurant', 'website': 'http://www.rajabaari.fi/', 'snowmobile': 'yes', 'opening_hours': 'Mo-Fr 09:00-22:00;Sa 10:00-19:00;Su 11:00-20:00'}
# {'name': 'Tunturikeskus Galdotieva', 'phone': '+358 (0)16 528 630', 'amenity': 'restaurant', 'cuisine': 'regional', 'smoking': 'outside', 'website': 'https://www.harriniva.fi/fi/kohteet/tunturikeskus-galdotieva', 'delivery': 'no', 'operator': 'Harrinivan Lomakeskus', 'takeaway': 'yes', 'addr:city': 'Leppäjärvi', 'snowmobile': 'yes', 'addr:street': 'Ruijantie', 'addr:postcode': '99440', 'opening_hours': 'Mo-Su 10:00-20:00', 'addr:housenumber': '2605'}
# {'name': 'Kilpisjärven retkeilykeskus', 'amenity': 'restaurant', 'cuisine': 'regional', 'smoking': 'outside', 'website': 'http://www.kilpisjarvi.info/', 'delivery': 'no', 'takeaway': 'yes', 'addr:city': 'Kilpisjärvi', 'snowmobile': 'yes', 'addr:street': 'Käsivarrentie', 'addr:postcode': '99490', 'addr:housenumber': '14663'}
# {'name': 'Restaurang Zenzei', 'phone': '+46 922-100 00', 'amenity': 'restaurant', 'addr:city': 'Haparanda', 'addr:street': 'Norra Esplanaden', 'addr:country': 'SE', 'addr:postcode': '95331', 'opening_hours': 'Mo-Th 10:00-21:00; Fr-Sa 12:00-22:00; Su 12:00-20:00', 'addr:housenumber': '4'}
# {'name': 'Restaurang Leilani', 'amenity': 'restaurant', 'cuisine': 'chinese;pizza', 'website': 'http://www.restaurangleilani.com/', 'addr:postcode': '95322', 'opening_hours': 'Mo 10:00-21:00; Tu-Fr 10:00-22:00; Sa 12:00-22:00; Su 12:00-21:00', 'addr:housenumber': '15'}
# {'name': 'Minerva', 'email': 'info@svefi.net', 'phone': '+46-922-688-07', 'amenity': 'restaurant', 'website': 'http://minerva.svefi.net/', 'addr:street': 'Torget', 'addr:country': 'SE', 'addr:postcode': '95332', 'addr:housenumber': '3'}
# {'name': 'Tinas', 'amenity': 'restaurant', 'cuisine': 'fast_food'}
# {'name': 'Ravintola Kilpis', 'phone': '+358 45 157 2552', 'amenity': 'restaurant', 'cuisine': 'regional', 'smoking': 'outside', 'website': 'http://www.kilpishalli.fi/ravintolakilpis', 'delivery': 'no', 'takeaway': 'yes', 'addr:city': 'Kilpisjärvi', 'snowmobile': 'yes', 'addr:street': 'Käsivarrentie', 'addr:postcode': '99490', 'opening_hours': 'Mo-Th 11:00-16:00;Fr-Sa 12:00-18:00;Su 13:00-17:00'}
# {'name': 'Deatnu', 'amenity': 'restaurant', 'building': 'yes'}
# {'phone': '+358406882200', 'amenity': 'restaurant', 'website': 'https://www.jussantupa.fi/', 'addr:city': 'Enontekiö', 'snowmobile': 'yes', 'addr:street': 'Ounastie', 'addr:postcode': '99400', 'addr:housenumber': '140'}
# {'name': 'Pub Rastigaisa', 'phone': '0407008154', 'amenity': 'restaurant', 'website': 'http://www.rastigaisa.net/PUB_RASTIGAISA.html', 'snowmobile': 'yes', 'opening_hours': 'Mo-Th 08:00-21:00; Fr 08:00-02:00; Sa 14:00-02:00; Su 14:00-21:00'}
# {'name': 'Staalonpesä', 'amenity': 'restaurant', 'smoking': 'outside', 'delivery': 'no', 'addr:city': 'Nuorgam', 'addr:street': 'Nuorgamintie'}
# {'name': 'Giellajohka', 'amenity': 'restaurant', 'cuisine': 'regional', 'addr:city': 'Kaamanen', 'addr:street': 'Karigasniementie', 'addr:postcode': '99910', 'opening_hours': 'Mo-Su 09:00-21:00', 'addr:housenumber': '2920'}
# {'amenity': 'restaurant'}
# {'name': 'Ravintola Guossi', 'phone': '+358 40 484 8171', 'amenity': 'restaurant', 'cuisine': 'regional', 'smoking': 'outside', 'delivery': 'no', 'takeaway': 'no', 'addr:city': 'Karigasniemi', 'snowmobile': 'yes', 'addr:street': 'Ylätenontie', 'addr:postcode': '99950', 'opening_hours': 'Mo-Su 16:00-23:00', 'addr:housenumber': '32'}
# {'name': 'Lounas- ja grilliravintola Hansabar', 'phone': '+358 40 484 8171', 'amenity': 'restaurant', 'cuisine': 'lunch', 'smoking': 'outside', 'website': 'http://hansabar.fi/', 'delivery': 'no', 'facebook': 'https://www.facebook.com/KMhansabar/', 'takeaway': 'yes', 'addr:city': 'Karigasniemi', 'addr:street': 'Ylätenontie', 'addr:postcode': '99950', 'opening_hours': 'Mo-Fr 11:00-14:00', 'addr:housenumber': '32'}
# {'name': 'Hotelli Korpikartano', 'email': 'korpikartano@korpikartano.fi', 'phone': '+358407774339', 'amenity': 'restaurant', 'tourism': 'hotel', 'website': 'https://www.korpikartano.fi/en/', 'addr:city': 'Inari', 'snowmobile': 'yes', 'addr:street': 'Meneskartanontie', 'addr:postcode': '99870', 'opening_hours': '"by appointment"', 'addr:housenumber': '71'}
# {'name': 'Tieva-Baari, Pokka', 'amenity': 'restaurant', 'website': 'https://tieva-baari.fi', 'snowmobile': 'yes'}
# {'name': 'Loimu', 'amenity': 'restaurant', 'cuisine': 'pizza', 'website': 'http://www.ravintolaloimu.fl', 'snowmobile': 'yes', 'opening_hours': 'Su-We off; Th 14:00-20:00; Fr-Sa 14:00-22:00'}
# {'name': 'Ahkun Tupa', 'amenity': 'restaurant', 'cuisine': 'regional', 'website': 'https://www.ahkuntupa.fi/', 'addr:city': 'Lemmenjoki', 'snowmobile': 'yes', 'addr:postcode': '99885'}
# {'amenity': 'restaurant'}
# {'amenity': 'restaurant'}
# {'name': 'Neste Inari', 'amenity': 'restaurant', 'cuisine': 'pizza'}
# {'bar': 'yes', 'name': 'Ivalo River Camping', 'amenity': 'restaurant', 'capacity': '60', 'addr:city': 'Ivalo', 'addr:street': 'Kerttuojantie', 'addr:postcode': '99800', 'outdoor_seating': 'summer', 'addr:housenumber': '1'}
# {'name': 'Sarrit', 'email': 'ravintola@sarrit.inet.fi', 'phone': '+358 40 700 6485', 'amenity': 'restaurant', 'cuisine': 'regional', 'website': 'http://www.siida.fi/contents/restaurant', 'addr:city': 'Inari', 'wheelchair': 'yes', 'addr:street': 'Inarintie', 'addr:postcode': '99870', 'addr:housenumber': '46'}
# {'amenity': 'restaurant', 'addr:city': 'Inari', 'addr:street': 'Inarintie', 'addr:postcode': '99870'}
# {'name': 'Laanihovi', 'phone': '+358 45 6525 818', 'amenity': 'restaurant', 'leisure': 'dance', 'website': 'www.laanihovi.fi', 'snowmobile': 'yes', 'addr:street': 'Viskitie', 'dance:style': 'ballroom', 'opening_hours': '12:00-22:00', 'piste:amenity': 'cafe'}
# {'name': 'Kultahippu', 'phone': '+358 16 320 8800', 'amenity': 'restaurant', 'cuisine': 'regional', 'karaoke': 'yes', 'leisure': 'dance', 'smoking': 'outside', 'website': 'http://www.hotellikultahippu.fi', 'delivery': 'no', 'takeaway': 'no', 'addr:city': 'Ivalo', 'addr:street': 'Petsamontie', 'dance:style': 'ballroom', 'addr:country': 'FI', 'addr:postcode': '99800', 'internet_access': 'wlan', 'addr:housenumber': '1', 'internet_access:fee': 'no'}
# {'name': 'Laanilan Kievari', 'amenity': 'restaurant'}
# {'name': 'Kieppi', 'phone': '+358 16 554 4600', 'amenity': 'restaurant', 'website': 'http://www.hotellikieppi.fi', 'addr:city': 'Saariselkä', 'addr:country': 'FI', 'addr:postcode': '99830'}
# {'name': 'Teerenpesä', 'phone': '+358 16 668 001', 'amenity': 'restaurant', 'leisure': 'dance', 'smoking': 'outside', 'website': 'https://teerenpesa.fi/', 'addr:city': 'Saariselkä', 'addr:street': 'Saariseläntie', 'dance:style': 'ballroom', 'addr:country': 'FI', 'addr:postcode': '99830', 'opening_hours': 'mo-su 12:00-23:00', 'addr:housenumber': '5'}
# {'name': 'Kaltio', 'amenity': 'restaurant', 'addr:city': 'Saariselkä', 'addr:country': 'FI', 'addr:postcode': '99830'}
# {'name': 'Pirtti', 'amenity': 'restaurant', 'leisure': 'dance', 'website': 'http://www.tunturihotelli.fi', 'addr:city': 'Saariselkä', 'dance:style': 'ballroom', 'addr:country': 'FI', 'addr:postcode': '99830'}
# {'name': 'Lapin Yö', 'amenity': 'restaurant', 'website': 'https://www.hotelivalo.fi/', 'addr:city': 'Ivalo', 'addr:country': 'FI', 'addr:postcode': '99800'}
# {'name': 'Rakka', 'phone': '+358 3 06866322', 'amenity': 'restaurant', 'cuisine': 'regional', 'smoking': 'outside', 'website': 'https://www.holidayclubresorts.com/', 'addr:city': 'Saariselkä', 'addr:street': 'Saariseläntie', 'addr:country': 'FI', 'addr:postcode': '99830', 'opening_hours': 'mo-su 16:00-21:30', 'addr:housenumber': '7'}
# {'name': 'Pirkon Pritti', 'email': 'mail@pirkonpirtti.fi', 'phone': '+35816668050', 'amenity': 'restaurant', 'cuisine': 'regional', 'name:fi': 'Pirkon Pritti', 'website': 'https://www.pirkonpirtti.fi/', 'addr:postcode': '99830', 'opening_hours': 'Mo-Su 15:00-23:00', 'internet_access': 'wlan'}
# {'name': 'Pirkon Pirtti', 'phone': '+358 16 668 050', 'amenity': 'restaurant', 'website': 'https://www.pirkonpirtti.fi/', 'addr:city': 'Saariselkä', 'addr:country': 'FI', 'addr:postcode': '99830'}
# {'name': 'Petronella', 'email': 'petronella@ravintolapetronella.fi', 'phone': '+358 16 668930', 'amenity': 'restaurant', 'cuisine': 'regional', 'smoking': 'outside', 'website': 'http://www.ravintolapetronella.fi/', 'addr:city': 'Saariselkä', 'addr:street': 'Honkapolku', 'addr:country': 'FI', 'addr:postcode': '99830', 'addr:housenumber': '5'}
# {'name': 'Bistro Siberia', 'email': 'info@ravintolasiberia.fi', 'phone': '+358 40 5020409', 'amenity': 'restaurant', 'cuisine': 'fine_dining', 'smoking': 'outside', 'website': 'http://www.ravintolasiberia.fi/', 'addr:city': 'Saariselkä', 'addr:street': 'Saariseläntie', 'addr:country': 'FI', 'addr:postcode': '99830', 'opening_hours': 'mo-sa 12:00-15:00;su off', 'addr:housenumber': '3'}
# {'name': 'Huippu-ravintola', 'phone': '+358 16 668 803', 'amenity': 'restaurant', 'addr:city': 'Saariselkä', 'addr:street': 'Kaunispääntie', 'addr:postcode': '99830'}
# {'name': 'Tunturikeskus Kiilopää', 'amenity': 'restaurant', 'website': 'https://www.suomenlatu.fi/kiilopaa/ravintolat/'}
# {'name': 'Pilkku', 'amenity': 'restaurant'}
# {'amenity': 'restaurant'}
# {'name': 'Aurora West Reception', 'amenity': 'restaurant', 'cuisine': 'Finnish', 'smoking': 'no', 'delivery': 'no', 'takeaway': 'no', 'outdoor_seating': 'no'}
# {'name': 'Sevetin baari', 'amenity': 'restaurant', 'website': 'www.facebook.com/Sevetinbaari', 'snowmobile': 'yes'}
# {'name': 'Erähotelli Nellim', 'amenity': 'restaurant', 'website': 'https://nellim.fi/fi/', 'snowmobile': 'yes'}
# {'name': 'Sanila', 'amenity': 'restaurant', 'website': 'http://www.sanila.fi', 'snowmobile': 'yes'}

# %% [markdown]
# 4) This is how you make a geodataframe if needed:

# %%
restaurant_frame = to_gdf(restaurants)

# %%
restaurant_frame
# Out:
#          node_id                                               tags  \
# 0     4438886434                          {'amenity': 'restaurant'}
# 1      357246287  {'name': 'Ravintola HSF', 'amenity': 'restaura...
# 2     4710670610  {'name': 'SEO-restaurang', 'amenity': 'restaur...
# 3      834024571  {'name': 'Neljän tuulen tupa', 'amenity': 'res...
# 4      834024550  {'name': 'Hangon Casino', 'amenity': 'restaura...
# ...          ...                                                ...
# 4205  6062593013  {'name': 'Aurora West Reception', 'amenity': '...
# 4206  2724935927  {'name': 'Tunturikeskus Kiilopää', 'amenity': ...
# 4207  4033038097  {'name': 'Sevetin baari', 'amenity': 'restaura...
# 4208  4132699127  {'name': 'Erähotelli Nellim', 'amenity': 'rest...
# 4209  2198254459  {'name': 'Sanila', 'amenity': 'restaurant', 'w...
#
#                               geometry
# 0      POINT (2605875.856 8377824.720)
# 1      POINT (2556500.486 8360002.384)
# 2      POINT (2593263.881 8379464.609)
# 3      POINT (2561215.077 8360671.989)
# 4      POINT (2557876.428 8360644.882)
# ...                                ...
# 4205  POINT (3036674.293 10545200.128)
# 4206  POINT (3057017.451 10550890.503)
# 4207  POINT (3183732.349 10910699.174)
# 4208  POINT (3152571.631 10702968.949)
# 4209  POINT (3213823.867 10935845.798)
#
# [4210 rows x 3 columns]

# %% [markdown]
# 5) This is how you plot any sqlalchemy query:

# %%
get_map(restaurants)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %%
get_map(bars)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %%
get_map(pubs)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %% [markdown]
# 6) This is how you combine tags to collect data

# %%
pöhinä = session.query(OSMPoint).filter(OSMPoint.tags['amenity'].astext.in_(
    ['restaurant','bar','pub','biergarten','cafe','fast_food','food_court','ice_cream']
))
pöhinä.count()
# Out:
# 10054

# %%
get_map(pöhinä)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %%
culture = session.query(OSMPoint).filter(OSMPoint.tags['amenity'].astext.in_(
    ['arts_centre','cinema','community_centre','conference_centre','events_venue','nightclub','theatre']
))
culture.count()
# Out:
# 799

# %%
get_map(culture)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %% [markdown]
# 7) This is how you check the presence of a tag

# %%
shops = session.query(OSMPoint).filter(OSMPoint.tags.has_key('shop'))
shops.count()
# Out:
# 15186

# %%
get_map(shops)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %% [markdown]
# 8) Let's add H3 index then. `RESOLUTION` is the H3 aperture size

# %%
RESOLUTION = 9
pöhinä_frame = to_gdf(pöhinä)
pöhinä_frame = pöhinä_frame.to_crs(epsg=4326)
pöhinä_frame
# Out:
#           node_id                                               tags  \
# 0      1113869600  {'name': 'Jussarö vierassatama', 'shop': 'souv...
# 1       443835928  {'amenity': 'cafe', 'addr:street': 'Boxvägen',...
# 2      4438886434                          {'amenity': 'restaurant'}
# 3      6482584428  {'amenity': 'cafe', 'opening_hours': 'around f...
# 4      8676554451                                {'amenity': 'cafe'}
# ...           ...                                                ...
# 10015  2198254459  {'name': 'Sanila', 'amenity': 'restaurant', 'w...
# 10016  4132699127  {'name': 'Erähotelli Nellim', 'amenity': 'rest...
# 10017  2724963020  {'name': 'Tankavaara, Wanhan Waskoolimiehen Ka...
# 10018  4033038097  {'name': 'Sevetin baari', 'amenity': 'restaura...
# 10019  4033104244  {'name': 'Rajamotelli Näätämö', 'amenity': 'ca...
#
#                         geometry
# 0      POINT (23.57064 59.82943)
# 1      POINT (23.62736 59.93926)
# 2      POINT (23.40898 59.90143)
# 3      POINT (23.41828 59.94652)
# 4      POINT (23.31935 59.92347)
# ...                          ...
# 10015  POINT (28.87027 69.58775)
# 10016  POINT (28.32003 68.84552)
# 10017  POINT (27.09935 68.18065)
# 10018  POINT (28.59995 69.50882)
# 10019  POINT (29.10925 69.66740)
#
# [10020 rows x 3 columns]

# %% [markdown]
# 9) Aggregate rows based on hex index

# %%
hex_col = 'hex' + str(RESOLUTION)
pöhinä_frame[hex_col] = pöhinä_frame['geometry'].apply(lambda geom: geo_to_h3(geom.y, geom.x, RESOLUTION),1)
pöhinä_counts = pöhinä_frame.groupby(hex_col).size().to_frame(name='count')
pöhinä_counts
# Out:
#                  count
# hex9
# 89012618273ffff      1
# 89012619513ffff      1
# 89012619517ffff      1
# 8901261958fffff      2
# 8901264c60bffff      1
# ...                ...
# 89112ecd823ffff      1
# 89112ecd82bffff      1
# 89112ecdd0bffff      1
# 89112ed1323ffff      2
# 89112ed1337ffff      1
#
# [4615 rows x 1 columns]

# %% [markdown]
# 10) Add centroid to each hex, in case we want to plot it with other tools. Of course, H3 has the coordinates reversed wrt. shapely

# %%
centroid_lat_lon = pöhinä_counts.index.map(lambda index: h3_to_geo(index))
pöhinä_counts['geometry']= [Point(geom[1], geom[0]) for geom in centroid_lat_lon]
pöhinä_counts[hex_col] = pöhinä_counts.index
pöhinä_counts = gpd.GeoDataFrame(pöhinä_counts, geometry='geometry', crs=pöhinä_frame.crs)
# Out:
# {'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': '5tldd4g', 'type': 'geojson', 'config': {'dataId': 'data_1', 'label': 'data_1', 'color': [241, 92, 23], 'columns': {'geojson': 'geometry'}, 'isVisible': False, 'visConfig': {'opacity': 0.8, 'strokeOpacity': 0.8, 'thickness': 0.5, 'strokeColor': None, 'colorRange': {'name': 'Global Warming', 'type': 'sequential', 'category': 'Uber', 'colors': ['#5A1846', '#900C3F', '#C70039', '#E3611C', '#F1920E', '#FFC300']}, 'strokeColorRange': {'name': 'Global Warming', 'type': 'sequential', 'category': 'Uber', 'colors': ['#5A1846', '#900C3F', '#C70039', '#E3611C', '#F1920E', '#FFC300']}, 'radius': 10, 'sizeRange': [0, 10], 'radiusRange': [0, 50], 'heightRange': [0, 500], 'elevationScale': 5, 'stroked': False, 'filled': True, 'enable3d': False, 'wireframe': False}, 'hidden': False, 'textLabel': [{'field': None, 'color': [255, 255, 255], 'size': 18, 'offset': [0, 0], 'anchor': 'start', 'alignment': 'center'}]}, 'visualChannels': {'colorField': None, 'colorScale': 'quantile', 'sizeField': None, 'sizeScale': 'linear', 'strokeColorField': None, 'strokeColorScale': 'quantile', 'heightField': None, 'heightScale': 'linear', 'radiusField': None, 'radiusScale': 'linear'}}, {'id': 'k21aij8', 'type': 'hexagonId', 'config': {'dataId': 'data_1', 'label': 'hex8', 'color': [34, 63, 154], 'columns': {'hex_id': 'hex8'}, 'isVisible': True, 'visConfig': {'opacity': 0.8, 'colorRange': {'name': 'Global Warming', 'type': 'sequential', 'category': 'Uber', 'colors': ['#5A1846', '#900C3F', '#C70039', '#E3611C', '#F1920E', '#FFC300']}, 'coverage': 1, 'enable3d': False, 'sizeRange': [0, 500], 'coverageRange': [0, 1], 'elevationScale': 5}, 'hidden': False, 'textLabel': [{'field': None, 'color': [255, 255, 255], 'size': 18, 'offset': [0, 0], 'anchor': 'start', 'alignment': 'center'}]}, 'visualChannels': {'colorField': {'name': 'count', 'type': 'integer'}, 'colorScale': 'quantize', 'sizeField': None, 'sizeScale': 'linear', 'coverageField': None, 'coverageScale': 'linear'}}], 'interactionConfig': {'tooltip': {'fieldsToShow': {'data_1': [{'name': 'count', 'format': None}, {'name': 'hex8', 'format': None}]}, 'compareMode': False, 'compareType': 'absolute', 'enabled': True}, 'brush': {'size': 0.5, 'enabled': False}, 'geocoder': {'enabled': False}, 'coordinate': {'enabled': False}}, 'layerBlending': 'normal', 'splitMaps': [], 'animationConfig': {'currentTime': None, 'speed': 1}}, 'mapState': {'bearing': 0, 'dragRotate': False, 'latitude': 60.14247930383862, 'longitude': 23.784654539638225, 'pitch': 0, 'zoom': 6.382620658788189, 'isSplit': False}, 'mapStyle': {'styleType': 'dark', 'topLayerGroups': {}, 'visibleLayerGroups': {'label': True, 'road': True, 'border': False, 'building': True, 'water': True, 'land': True, '3d building': False}, 'threeDBuildingColor': [9.665468314072013, 17.18305478057247, 31.1442867897876], 'mapStyles': {}}}}
# hex8
# {'version': 'v1',
#  'config': {'visState': {'filters': [],
#    'layers': [{'id': '5tldd4g',
#      'type': 'geojson',
#      'config': {'dataId': 'data_1',
#       'label': 'data_1',
#       'color': [241, 92, 23],
#       'columns': {'geojson': 'geometry'},
#       'isVisible': False,
#       'visConfig': {'opacity': 0.8,
#        'strokeOpacity': 0.8,
#        'thickness': 0.5,
#        'strokeColor': None,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'strokeColorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'radius': 10,
#        'sizeRange': [0, 10],
#        'radiusRange': [0, 50],
#        'heightRange': [0, 500],
#        'elevationScale': 5,
#        'stroked': False,
#        'filled': True,
#        'enable3d': False,
#        'wireframe': False},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center'}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear',
#       'strokeColorField': None,
#       'strokeColorScale': 'quantile',
#       'heightField': None,
#       'heightScale': 'linear',
#       'radiusField': None,
#       'radiusScale': 'linear'}},
#     {'id': 'k21aij8',
#      'type': 'hexagonId',
#      'config': {'dataId': 'data_1',
#       'label': 'hex9',
#       'color': [34, 63, 154],
#       'columns': {'hex_id': 'hex9'},
#       'isVisible': True,
#       'visConfig': {'opacity': 0.8,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'coverage': 1,
#        'enable3d': False,
#        'sizeRange': [0, 500],
#        'coverageRange': [0, 1],
#        'elevationScale': 5},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center'}]},
#      'visualChannels': {'colorField': {'name': 'count', 'type': 'integer'},
#       'colorScale': 'quantize',
#       'sizeField': None,
#       'sizeScale': 'linear',
#       'coverageField': None,
#       'coverageScale': 'linear'}}],
#    'interactionConfig': {'tooltip': {'fieldsToShow': {'data_1': [{'name': 'count',
#         'format': None},
#        {'name': 'hex8', 'format': None}]},
#      'compareMode': False,
#      'compareType': 'absolute',
#      'enabled': True},
#     'brush': {'size': 0.5, 'enabled': False},
#     'geocoder': {'enabled': False},
#     'coordinate': {'enabled': False}},
#    'layerBlending': 'normal',
#    'splitMaps': [],
#    'animationConfig': {'currentTime': None, 'speed': 1}},
#   'mapState': {'bearing': 0,
#    'dragRotate': False,
#    'latitude': 60.14247930383862,
#    'longitude': 23.784654539638225,
#    'pitch': 0,
#    'zoom': 6.382620658788189,
#    'isSplit': False},
#   'mapStyle': {'styleType': 'dark',
#    'topLayerGroups': {},
#    'visibleLayerGroups': {'label': True,
#     'road': True,
#     'border': False,
#     'building': True,
#     'water': True,
#     'land': True,
#     '3d building': False},
#    'threeDBuildingColor': [9.665468314072013,
#     17.18305478057247,
#     31.1442867897876],
#    'mapStyles': {}}}}

# %% [markdown]
# We may also customize the map config so that the hex column is used regardless of resolution

# %%
from kepler_h3_config import config
hex_column = next((column for column in pöhinä_counts.columns if column.startswith('hex')), False)
for layer in config['config']['visState']['layers']:
    if layer["type"] == "hexagonId" and hex_column:
        print(layer["config"]["label"])
        layer["config"]["label"] = hex_column
        layer["config"]["columns"]["hex_id"] = hex_column

# %% [markdown]
# 11) Anyway, all of the above is done automatically by get_h3_map now

# %%
from kepler_h3_config import config
map = get_h3_map(pöhinä, 9, config=config)
map
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': '5tldd4g', 'type': …

# %% [markdown]
# You may use an existing kepler config to change map styling:

# %%
map.config = config

# %%
map.config
# Out:
# {'version': 'v1',
#  'config': {'visState': {'filters': [],
#    'layers': [{'id': '5tldd4g',
#      'type': 'geojson',
#      'config': {'dataId': 'data_1',
#       'label': 'data_1',
#       'color': [241, 92, 23],
#       'columns': {'geojson': 'geometry'},
#       'isVisible': False,
#       'visConfig': {'opacity': 0.8,
#        'strokeOpacity': 0.8,
#        'thickness': 0.5,
#        'strokeColor': None,
#        'colorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'strokeColorRange': {'name': 'Global Warming',
#         'type': 'sequential',
#         'category': 'Uber',
#         'colors': ['#5A1846',
#          '#900C3F',
#          '#C70039',
#          '#E3611C',
#          '#F1920E',
#          '#FFC300']},
#        'radius': 10,
#        'sizeRange': [0, 10],
#        'radiusRange': [0, 50],
#        'heightRange': [0, 500],
#        'elevationScale': 5,
#        'stroked': False,
#        'filled': True,
#        'enable3d': False,
#        'wireframe': False},
#       'hidden': False,
#       'textLabel': [{'field': None,
#         'color': [255, 255, 255],
#         'size': 18,
#         'offset': [0, 0],
#         'anchor': 'start',
#         'alignment': 'center'}]},
#      'visualChannels': {'colorField': None,
#       'colorScale': 'quantile',
#       'sizeField': None,
#       'sizeScale': 'linear',
#       'strokeColorField': None,
#       'strokeColorScale': 'quantile',
#       'heightField': None,
#       'heightScale': 'linear',
#       'radiusField': None,
#       'radiusScale': 'linear'}}],
#    'interactionConfig': {'tooltip': {'fieldsToShow': {'data_1': [{'name': 'count',
#         'format': None}]},
#      'compareMode': False,
#      'compareType': 'absolute',
#      'enabled': True},
#     'brush': {'size': 0.5, 'enabled': False},
#     'geocoder': {'enabled': False},
#     'coordinate': {'enabled': False}},
#    'layerBlending': 'normal',
#    'splitMaps': [],
#    'animationConfig': {'currentTime': None, 'speed': 1}},
#   'mapState': {'bearing': 0,
#    'dragRotate': False,
#    'latitude': 60.16873006531405,
#    'longitude': 24.79718904180311,
#    'pitch': 0,
#    'zoom': 8.948847469054556,
#    'isSplit': False},
#   'mapStyle': {'styleType': 'dark',
#    'topLayerGroups': {},
#    'visibleLayerGroups': {'label': True,
#     'road': True,
#     'border': False,
#     'building': True,
#     'water': True,
#     'land': True,
#     '3d building': False},
#    'threeDBuildingColor': [9.665468314072013,
#     17.18305478057247,
#     31.1442867897876],
#    'mapStyles': {}}}}

# %% [markdown]
# 12) Let's check transit stops next

# %%
stations = session.query(OSMPoint).filter((OSMPoint.tags['railway'].astext=='station')|(OSMPoint.tags['station'].astext=='subway')|(OSMPoint.tags['amenity'].astext=='bus_station'))
stations.count()
# Out:
# 365

# %%
stops = session.query(OSMPoint).filter((OSMPoint.tags['highway'].astext=='bus_stop')|(OSMPoint.tags['railway'].astext=='tram_stop')|(OSMPoint.tags['amenity'].astext=='bus_station'))
stops.count()
# Out:
# 93855

# %%
get_map(stations)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %%
get_map(stops)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %%
get_h3_map(stations,7)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…

# %%
get_h3_map(stops,8)
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [], 'interactionConfig': {'…
